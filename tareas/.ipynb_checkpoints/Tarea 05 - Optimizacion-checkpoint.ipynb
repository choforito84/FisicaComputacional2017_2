# %%
using Plots, Interact

# %% [markdown]
# # Tarea 5: Optimización
#
# ## Para entregarse el jueves 16 marzo 2017, antes de las 15:00

# %% [markdown]
# Una tarea importante en la ciencia computacional es la **optimización**, es decir, encontrar máximos y mínimos de funciones. Representa una aplicación de suma importancia de derivadas, como aprendimos en Cálculo 1 y 3 y en el notebook 7.
#
# [1] Escribe una función que toma una función $f:\mathbb{R} \to \mathbb{R}$ lisa (es decir, suficientemente diferenciable), y utiliza el método de Newton para encontrar:
# (i) los valores de $x$ en los cuales la función toma su valor máximo y mínimo;
# (ii) el valor ahí;
# (iii) si es un máximo o un mínimo.
#
# [Pista: ¿Cuáles son las condiciones matemáticas que se deben cumplir para (i) y (iii)?]

# %% [markdown]
# ### [1]
#
# Sabemos que, para una función $f: \mathbb{R} \to \mathbb{R}$, la condición de un punto $x_0$ para ser mínimo o máximo es que $f'(x_0) = 0 $ Esto es conocido como el **criterio de la primera derivada** Si ahora queremos saber que clase de extremo es, es decir, si es un máximo o mínimo, podemos encontrarlo con el **criterio de la segunda derivada**, el cual dice que $f(x_0) > 0 \implies x_0 = min(f(x))$ y $f(x_0) \implies x_0 = max(f(x))$. Así, podemos utilizar el método de newton encontrándole raíces a la primera derivada de la función y evaluándolos después en la segunda derivada de la función, también aproximándola

# %%
function derv1(f :: Function, a :: Number, h :: Number = 1e-8)
    return (f(a+h)-f(a-h))/(2h)
end
function derv2(f :: Function, a :: Number, h :: Number =1e-8)
    return (f(big(a+h))+f(big(a-h)) - 2f(big(a)))/((h^2))
end
function extremos(f :: Function;test=false)
    x=rand()
    i=1
    while abs(derv1(f,x))>1e-15
        if i==1000
            return "fail"
        end
        if test==true
            @show (x,f(x),derv1(f,x))
        end
        i+=1
        x=x-(derv1(f,x)/derv2(f,x))
    end
    if derv2(f,x) > 0
        return "min = $(convert(Float64,f(x))), x = $(convert(Float64,x))"
    elseif derv2(f,x) < 0
        return "max = $(convert(Float64,f(x))), x = $(convert(Float64,x))"
    end
end
# Out:
# WARNING: Method definition derv1(
# extremos (generic function with 1 method)

# %%
extremos(x -> (sin(x)))
# Out:
# Function, Number) in module Main at In[87]:2 overwritten at In[108]:2
# "max = 1.0, x = 1.5707963267948966"

# %% [markdown]
# [2] Otro método para optimizar es darse cuenta de que la función misma te puede dar información sobre por dónde buscar.
#
# (i) Considerando una función $f:\mathbb{R} \to \mathbb{R}$, si empezamos en una posición inicial $x_0$, ¿en cuál dirección nos podríamos desplazar (por un paso chiquito) para ir hacia un mínimo?
#
# (ii) Impleméntalo, y dibuja la evolución en el tiempo del algoritmo, pintando la función como si fuera una colina, para distintas funciones.
#
# Este método se llama **descenso de gradiente**.

# %%
function descenso(f :: Function,paso=1e-1;test=false,list=false)
    x=[]
    push!(x,rand())
    i=1
    while abs(derv1(f,x[i]))>1e-5
        if i==10000
            return "fail"
        end
        if test==true
            @show (x[i],f(x[i]),derv1(f,x[i]))
        end
        push!(x,x[i]-paso*derv1(f,x[i]))
        i=i+1
    end
    if list==true
        return x
    else
        return x[end]
    end
end
# Out:
# .
# WARNING: Method definition derv1(Function, Number,
# descenso (generic function with 2 methods)

# %%
descenso(x->(x-3)^2,list=true)
# Out:
# Number) in module Main at In[87]:2 overwritten at In[108]:2.
# 60-element Array{Any,1}:
#  0.670966
#  1.13677
#  1.50942
#  1.80753
#  2.04603
#  2.23682
#  2.38946
#  2.51157
#  2.60925
#  2.6874
#  2.74992
#  2.79994
#  2.83995
#  ⋮
#  2.99995
#  2.99996
#  2.99997
#  2.99997
#  2.99998
#  2.99998
#  2.99999
#  2.99999
#  2.99999
#  2.99999
#  2.99999
#  3.0

# %%
function descensov(f :: Function)
    B=descenso(f,list=true)
    A=linspace(minimum(B)-.1,maximum(B)+.1,250)
    @manipulate for i in 1:length(B)
        plot(A,[f(x) for x in A],xlabel="x",ylabel="f(x)",title="Descenso de gradiente",label="f(x)")
        scatter!([B[i]],[f(B[i])],markersize=6,label="n \=$i")
    end
end
# Out:
# WARNING: Method definition derv2(Function, Number) in module Main at In[87]:5 overwritten at In[108]:5.
# WARNING: Method definition derv2(Function
# descensov (generic function with 1 method)

# %%
descensov(sin)
# Out:
# , Number, Number) in module Main at In[87]:5 overwritten at In[108]:5.
# WARNING: Method definition extremos(Function) in module Main at In[87]:8 overwritten at In[108]:8.
# WARNING: Method definition #extremos(Array{Any, 1}, Main.#extremos, Function) in module Main overwritten.
# WARNING: Method definition descenso(Function) in module Main at In[89]:2 overwritten at In[110]:2.
# WARNING: Method definition descenso(Function, Any) in module Main at In[89]:2 overwritten at In[110]:2.
# WARNING: Method definition #descenso(Array{Any, 1}, Main.#descenso, Function) in module Main overwritten.
# WARNING: Method definition #descenso(Array{Any, 1}, Main.#descenso, Function, Any) in module Main overwritten.
# WARNING: Method definition descensov(Function) in module Main at In[91]:2 overwritten at In[112]:2.
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 54.7703,369.674 596.063,369.674 596.063,23.3815 54.7703,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="54" y="23" width="542" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   214.611,364.48 214.611,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   430.06,364.48 430.06,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,359.876 587.944,359.876
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,260.501 587.944,260.501
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,161.127 587.944,161.127
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,61.7522 587.944,61.7522
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   214.611,369.674 214.611,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   430.06,369.674 430.06,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,369.674 54.7703,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,359.876 62.8897,359.876
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,260.501 62.8897,260.501
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,161.127 62.8897,161.127
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,61.7522 62.8897,61.7522
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 214.611, 381.674)" x="214.611" y="381.674">-1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 430.06, 381.674)" x="430.06" y="381.674">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 364.376)" x="53.5703" y="364.376">-1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 265.001)" x="53.5703" y="265.001">-0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 165.627)" x="53.5703" y="165.627">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 66.2522)" x="53.5703" y="66.2522">0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 325.417, 18)" x="325.417" y="18">Descenso de gradiente</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 325.417, 397.6)" x="325.417" y="397.6">x</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 196.528)" x="14.4" y="196.528">f(x)</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.0899,358.883 72.1408,359.063 74.1916,359.225 76.2424,359.369 78.2932,359.495 80.344,359.603 82.3948,359.693 84.4457,359.765 86.4965,359.819 88.5473,359.855
#   90.5981,359.873 92.6489,359.873 94.6997,359.855 96.7506,359.82 98.8014,359.766 100.852,359.694 102.903,359.604 104.954,359.496 107.005,359.37 109.055,359.226
#   111.106,359.064 113.157,358.885 115.208,358.687 117.259,358.471 119.31,358.238 121.36,357.987 123.411,357.718 125.462,357.431 127.513,357.126 129.564,356.803
#   131.614,356.463 133.665,356.105 135.716,355.73 137.767,355.337 139.818,354.926 141.869,354.497 143.919,354.051 145.97,353.588 148.021,353.107 150.072,352.609
#   152.123,352.094 154.173,351.561 156.224,351.011 158.275,350.443 160.326,349.859 162.377,349.257 164.428,348.639 166.478,348.003 168.529,347.351 170.58,346.681
#   172.631,345.995 174.682,345.292 176.732,344.572 178.783,343.836 180.834,343.083 182.885,342.314 184.936,341.528 186.987,340.726 189.037,339.908 191.088,339.073
#   193.139,338.223 195.19,337.356 197.241,336.473 199.291,335.575 201.342,334.66 203.393,333.73 205.444,332.784 207.495,331.823 209.546,330.846 211.596,329.854
#   213.647,328.847 215.698,327.824 217.749,326.786 219.8,325.734 221.85,324.666 223.901,323.584 225.952,322.486 228.003,321.375 230.054,320.248 232.104,319.107
#   234.155,317.952 236.206,316.783 238.257,315.6 240.308,314.402 242.359,313.191 244.409,311.966 246.46,310.727 248.511,309.475 250.562,308.209 252.613,306.93
#   254.663,305.638 256.714,304.333 258.765,303.015 260.816,301.683 262.867,300.34 264.918,298.983 266.968,297.614 269.019,296.233 271.07,294.839 273.121,293.433
#   275.172,292.016 277.222,290.586 279.273,289.145 281.324,287.692 283.375,286.227 285.426,284.752 287.477,283.265 289.527,281.767 291.578,280.258 293.629,278.738
#   295.68,277.208 297.731,275.667 299.781,274.116 301.832,272.554 303.883,270.983 305.934,269.401 307.985,267.81 310.036,266.209 312.086,264.598 314.137,262.978
#   316.188,261.349 318.239,259.711 320.29,258.064 322.34,256.408 324.391,254.743 326.442,253.07 328.493,251.389 330.544,249.7 332.595,248.002 334.645,246.296
#   336.696,244.583 338.747,242.863 340.798,241.134 342.849,239.399 344.899,237.657 346.95,235.907 349.001,234.151 351.052,232.388 353.103,230.619 355.154,228.843
#   357.204,227.062 359.255,225.274 361.306,223.481 363.357,221.681 365.408,219.877 367.458,218.067 369.509,216.252 371.56,214.432 373.611,212.607 375.662,210.777
#   377.713,208.943 379.763,207.105 381.814,205.262 383.865,203.416 385.916,201.565 387.967,199.711 390.017,197.853 392.068,195.993 394.119,194.128 396.17,192.261
#   398.221,190.392 400.271,188.519 402.322,186.644 404.373,184.767 406.424,182.887 408.475,181

# %% [markdown]
# [3] Podemos utilizar el descenso de gradiente también para buscar mínimos de funciones $f:\mathbb{R^n} \to \mathbb{R}$. Hazlo para algunas funciones $f:\mathbb{R}^2 \to \mathbb{R}$ y dibuja la evolución.
#
# Una versión estocástica del descenso de gradiente se utiliza mucho hoy día en aplicaciones de aprendizaje automático ("machine learning").

# %%
#[3]
function gradiente(f::Function,A,h=1e-8)
    return [(f(A+[h,0])-f(A))/h,(f(A+[0,h])-f(A))/h]
end
function descenso2(f :: Function,paso=1e-1;test=false,list=false)
    x=[]
    push!(x,rand(2))
    i=1
    while norm(gradiente(f,x[i]))>1e-5
        if i==10000
            return "fail"
        end
        if test==true
            @show (x[i],f(x[i]),gradiente(f,x[i]))
        end
        push!(x,x[i]-paso*gradiente(f,x[i]))
        i=i+1
    end
    if list==true
        return x
    else
        return x[end]
    end
end
g(A)=sin(A[1])+cos(A[2])
# Out:
# WARNING: Method definition gradiente(Function, Any) in module Main at In[93]:3 overwritten at In[114]:3.
# WARNING: Method definition
# g (generic function with 1 method)

# %%
gradiente(g,[1,1])
# Out:
# gradiente(Function, Any, Any
# 2-element Array{Float64,1}:
#   0.540302
#  -0.841471

# %%
function descenso2v(g :: Function)
    A=descenso2(g,list=true)
    M=zeros(length(A),3)
    for i in 1:length(A)
        M[i,1]=A[i][1]
        M[i,2]=A[i][2]
        M[i,3]=g(A[i])
    end
    X=linspace(minimum(M[:,1])-.1,maximum(M[:,1])+.1,100)
    Y=linspace(minimum(M[:,2])-.1,maximum(M[:,2])+.1,100)
    Z=[g([x,y]) for x in X, y in Y]
    @manipulate for i in 1:length(A)
        surface(X,Y,Z, alpha=.3,title="descenso de gradiente",label="f(x,y)",ylabel="y",xlabel="x",zlabel="f(x,y)")
        scatter3d!([M[i,1]],[M[i,2]],[M[i,3]],label="n = $i",color=:blues,markersize=8)
    end
end
descenso2v(g)
# Out:
# ) in module Main at In[93]:3 overwritten at In[114]:3.
# WARNING: Method definition descenso2(Function) in module Main at In[93]:6 overwritten at In[114]:6.
# WARNING: Method definition descenso2(Function, Any) in module Main at In[93]:6 overwritten at In[114]:6.
# WARNING: Method definition #descenso2(Array{Any, 1}, Main.#descenso2, Function) in module Main overwritten.
# WARNING: Method definition #descenso2(Array{Any, 1}, Main.#descenso2, Function, Any) in module Main overwritten.
# WARNING: Method definition g(Any) in module Main at In[93]:25 overwritten at In[114]:25.
# WARNING: Method definition descenso2v(Function) in module Main at In[106]:2 overwritten at In[116]:2.
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 28.1037,369.674 596.063,369.674 596.063,23.3815 28.1037,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="28" y="23" width="508" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,273.548 259.863,137.022
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   259.863,137.022 536.063,233.148
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,250.82 259.863,114.294
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   259.863,114.294 536.063,210.42
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,228.092 259.863,91.5656
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   259.863,91.5656 536.063,187.692
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,205.364 259.863,68.8376
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   259.863,68.8376 536.063,164.964
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,182.636 259.863,46.1095
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   259.863,46.1095 536.063,142.236
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,159.907 259.863,23.3815
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   259.863,23.3815 536.063,119.508
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.9311,283.929 289.69,147.403
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   289.69,147.403 289.69,33.7623
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   90.1493,295.142 321.909,158.616
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   321.909,158.616 321.909,44.9753
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   122.368,306.355 354.127,169.829
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   354.127,169.829 354.127,56.1883
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   154.586,317.568 386.345,181.042
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   386.345,181.042 386.345,67.4012
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   186.804,328.78 418.563,192.254
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   418.563,192.254 418.563,78.6142
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   219.022,339.993 450.782,203.467
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   450.782,203.467 450.782,89.8271
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   251.24,351.206 483,214.68
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   483,214.68 483,101.04
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   283.459,362.419 515.218,225.893
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   515.218,225.893 515.218,112.253
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   61.372,253.95 337.572,350.076
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   61.372,253.95 61.372,140.31
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   104.184,228.73 380.384,324.857
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   104.184,228.73 104.184,115.09
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   146.995,203.51 423.195,299.637
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   146.995,203.51 146.995,89.8702
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   189.807,178.291 466.007,274.417
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   189.807,178.291 189.807,64.6505
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   232.619,153.071 508.819,249.197
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   232.619,153.071 232.619,39.4308
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   1.37015,250.984 7.97575,253.283
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   10.9116,251.424 10.9116,251.013 11.2786,250.318 11.6455,250.034 12.3795,249.878 13.8474,250.389 14.5814,251.056 14.9483,251.595 15.3153,252.546 15.3153,253.368
#   14.9483,254.064 14.2144,255.042 10.5446,257.88 15.6823,259.668
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   12.7465,204.55 11.6455,204.578 10.9116,205.557 10.5446,207.486 10.5446,208.721 10.9116,210.905 11.6455,212.395 12.7465,213.19 13.4804,213.445 14.5814,213.417
#   15.3153,212.438 15.6823,210.509 15.6823,209.274 15.3153,207.089 14.5814,205.6 13.4804,204.805 12.7465,204.55
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   10.9116,160.512 10.9116,160.101 11.2786,159.406 11.6455,159.122 12.3795,158.966 13.8474,159.477 14.5814,160.144 14.9483,160.683 15.3153,161.633 15.3153,162.456
#   14.9483,163.151 14.2144,164.13 10.5446,166.967 15.6823,168.755
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   28.1037,273.548 28.1037,273.548 24.7041,275.55 28.1037

# %% [markdown]
# ## Mínimos cuadrados

# %% [markdown]
# La optimización es muy imporante en la estadística. Por ejemplo, podemos utilizar optimización para resolver el problema de mínimos cuadrados, como sigue.

# %% [markdown]
# [4] Genera unos datos artificiales $(x_i, y_i)$ cerca de una recta, utilizando `rand()` para generar números aleatorios.

# %%
#[4]
function datos(m :: Number,b :: Number,n::Int64 = 20)
    M=zeros(2,n)
    for i in 1:n
        M[1,i]=rand()*2
        M[2,i]=(m + rand())*M[1,i]+(b+rand())
    end
    return M
end
M=datos(5,9)
scatter(M[1,:],M[2,:],title="datos generados de manera arbitraria para m=5, b=9")
# Out:
# WARNING: Method definition datos(Number, Number) in module Main at In[96]:3
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 21.7148,384.952 596.063,384.952 596.063,23.3815 21.7148,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="21" y="23" width="575" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   31.6909,379.528 31.6909,28.805
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   310.853,379.528 310.853,28.805
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   590.014,379.528 590.014,28.805
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   30.33,369.118 587.448,369.118
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   30.33,223.17 587.448,223.17
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   30.33,77.2219 587.448,77.2219
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   31.6909,384.952 31.6909,379.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   310.853,384.952 310.853,379.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   590.014,384.952 590.014,379.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,384.952 21.7148,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,369.118 30.33,369.118
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,223.17 30.33,223.17
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   21.7148,77.2219 30.33,77.2219
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 31.6909, 396.952)" x="31.6909" y="396.952">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 310.853, 396.952)" x="310.853" y="396.952">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 590.014, 396.952)" x="590.014" y="396.952">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 20.5148, 373.618)" x="20.5148" y="373.618">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 20.5148, 227.67)" x="20.5148" y="227.67">15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 20.5148, 81.7219)" x="20.5148" y="81.7219">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 308.889, 18)" x="308.889" y="18">datos generados de manera arbitraria para m=5, b=9</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="208.44" cy="283.802" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="208.44" cy="283.802" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="574.648" cy="62.969" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="574.648" cy="62.969" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="300.93" cy="228.055" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="300.93" cy="228.055" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="68.7632" cy="370.469" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="68.7632" cy="370.469" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="552.919" cy="62.0611" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="552.919" cy="62.0611" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="446.16" cy="170.971" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="446.16" cy="170.971" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="517.135" cy="114.913" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="517.135" cy="114.913" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="105.799" cy="339.968" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="105.799" cy="339.968" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="500.77" cy="109.109" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="500.77" cy="109.109" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="415.152" cy="148.396" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="415.152" cy="148.396" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="394.972" cy="159.786" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="394.972" cy="159.786" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="234.905" cy="251.225" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="234.905" cy="251.225" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="267.093" cy="246.476" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="267.093" cy="246.476" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="102.275" cy="345.871" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="102.275" cy

# %% [markdown]
# [5] Queremos ajustar una recta $\ell(x)$ a los datos.
#
# (i) ¿Cuántos parámetros necesitaremos ajustar. Escribe una fórmula para $\ell$ en términos de estos parámetros.
#
# (ii) En mínimos cuadrados, para cada punto $(x_i, y_i)$ calculamos la distancia cuadrada vertical desde la recta $\ell$. La suma de todos ellos nos da una **función de costo** o **función de pérdida**, la cual queremos minimizar con respecto a las variables de la recta.
#
# Formula esto matemáticamente: ¿cuál función queremos minimizar, y qué satisface el mínimo?

# %% [markdown]
# ### [5]
# Sabemos que una recta en $\mathbb{R}^2$ se puede expresar como $(x,mx+b)$. Así, slo debemos ajustar dos parámetros para encontrar una recta que pase por los puntos deseados: $m$ y $b$. Así, para la colección de puntos $(x_i,y_i)$ que deseamos ajustar, la fórmula de la suma de la distancia al cuadrado vertical, es decir, de la segunda coordenada de todos estos puntos con respecto a la recta es:
#
# $$R^2 = \sum_{i=1}^{n} (y_i - (m x_i +b))^2$$
#
# Claramente, al sustituir los respectivos valores de $x_i$ y $y_i$, $R^2$ se volverá una función de $m$ y $b$. Así, debemos de minimizar esta función para obtener los parámetros de la recta que ajusta mejor esos datos. Es decir, obtener los valores de $m$ y $b$ tales que
#
# $$\frac{\partial(R^2)}{\partial m}= 0$$
#
# $$\frac{\partial(R^2)}{\partial b}= 0$$

# %% [markdown]
# [6] Utiliza el método de descenso de gradiente para resolver el problema. Dibuja el resultado - ¿es razonable? [Pista: Nota que tendrás que utilizar vectores (arreglos uni-dimensionales). En Julia, puedes operar con vectores utilizando operadores aritméticos, como si fueran vectores matemáticos.]

# %%
function minimoscuadrados(M)
    function rsquare(P)
        total=0
        for i in 1:size(M)[2]
            total=total+(M[2,i]-(P[1]*M[1,i]+P[2]))^2
        end
        return total
    end
    return descenso2(rsquare,1e-3)
end
# Out:
# .
# WARNING: Method definition datos(Number, Number, Int64) in module Main at In[96]:3 overwritten at In[117]:3.
# WARNING: Method definition minimoscuadrados(Any) in module Main at In[97]:2 overwritten
# minimoscuadrados (generic function with 1 method)

# %%
P=minimoscuadrados(M)
scatter(M[1,:],M[2,:],label="Datos originales",xlabel="x",ylabel="y",title="Ajuste por minimos cuadrados")
A=linspace(minimum(M[1,:]),maximum(M[1,:]),100)
plot!(A,[(P[1]*x +P[2]) for x in A],label="Ajuste")
# Out:
#  at In[118]:2.
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 36.9926,369.674 596.063,369.674 596.063,23.3815 36.9926,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="36" y="23" width="560" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   46.7033,364.48 46.7033,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   318.439,364.48 318.439,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   590.175,364.48 590.175,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   45.3786,347.854 587.677,347.854
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   45.3786,210.968 587.677,210.968
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   45.3786,74.0819 587.677,74.0819
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   46.7033,369.674 46.7033,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   318.439,369.674 318.439,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   590.175,369.674 590.175,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,369.674 36.9926,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,347.854 45.3786,347.854
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,210.968 45.3786,210.968
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,74.0819 45.3786,74.0819
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 46.7033, 381.674)" x="46.7033" y="381.674">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 318.439, 381.674)" x="318.439" y="381.674">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 590.175, 381.674)" x="590.175" y="381.674">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7926, 352.354)" x="35.7926" y="352.354">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7926, 215.468)" x="35.7926" y="215.468">15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7926, 78.5819)" x="35.7926" y="78.5819">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 316.528, 18)" x="316.528" y="18">Ajuste por minimos cuadrados</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 316.528, 397.6)" x="316.528" y="397.6">x</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 196.528)" x="14.4" y="196.528">y</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="218.75" cy="267.835" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="218.75" cy="267.835" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="575.217" cy="60.7139" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="575.217" cy="60.7139" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="308.78" cy="215.549" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="308.78" cy="215.549" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="82.7895" cy="349.121" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="82.7895" cy="349.121" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="554.067" cy="59.8625" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="554.067" cy="59.8625" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="450.147" cy="162.01" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="450.147" cy="162.01" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="519.234" cy="109.433" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="519.234" cy="109.433" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="118.84" cy="320.514" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="118.84" cy="320.514" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="503.305" cy="103.989" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="503.305" cy="103.989" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="419.964" cy="140.836" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="419.964" cy="140.836" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="400.322" cy="151.52" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="400.322" cy="151.52" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="244.512" cy="237.281" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="244.512" cy="2

# %%
gr()
X=rand(50)
Y=rand(50)
Z=rand(50)
surface(X,Y,Z)
scatter3d!(X,Y,Z)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 30.6037,384.952 596.063,384.952 596.063,3.93701 30.6037,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="30" y="3" width="506" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,279.187 261.222,128.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   261.222,128.972 536.063,234.737
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,263.558 261.222,113.342
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   261.222,113.342 536.063,219.107
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,247.928 261.222,97.7131
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   261.222,97.7131 536.063,203.478
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,232.299 261.222,82.0838
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   261.222,82.0838 536.063,187.849
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,216.67 261.222,66.4544
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   261.222,66.4544 536.063,172.219
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,201.04 261.222,50.8251
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   261.222,50.8251 536.063,156.59
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,185.411 261.222,35.1957
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   261.222,35.1957 536.063,140.961
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,169.782 261.222,19.5664
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   261.222,19.5664 536.063,125.331
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,154.152 261.222,3.93701
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   261.222,3.93701 536.063,109.702
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.9321,281.238 266.551,131.022
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   266.551,131.022 266.551,5.98751
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   102.839,306.985 333.457,156.769
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   333.457,156.769 333.457,31.7346
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   169.745,332.732 400.364,182.517
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   400.364,182.517 400.364,57.4817
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   236.651,358.479 467.27,208.264
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   467.27,208.264 467.27,83.2288
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   303.558,384.226 534.177,234.011
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   534.177,234.011 534.177,108.976
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   84.3761,244.162 359.217,349.927
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   84.3761,244.162 84.3761,119.127
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   141.379,207.033 416.22,312.797
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   141.379,207.033 141.379,81.9979
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   198.382,169.903 473.223,275.668
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   198.382,169.903 198.382,44.8685
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   255.385,132.774 530.226,238.539
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   255.385,132.774 255.385,7.73915
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   16.2578,246.935 15.1827,246.933 14.466,247.891 14.1076,249.81 14.1076,251.045 14.466,253.24 15.1827,254.75 16.2578,255.575 16.9745,255.851 18.0496,255.853
#   18.7663,254.894 19.1246,252.975 19.1246,251.741 18.7663,249.546 18.0496,248.036 16.9745,247.211 16.2578,246.935
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   5.50697,211.539 4.4319,211.537 3.71518,212.495 3.35682,214.414 3.35682,215.649 3.71518,217.844 4.4319,219.354 5.50697,220.179 6.22369,220.455 7.29877,220.457
#   8.01549,219.499 8.37385,217.579 8.37385,216.345 8.01549,214.15 7.29877,212.64 6.22369,211.815 5.50697,211.539
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   11.2407,221.563 10.8824,221.836 11.2407,222.385 11.5991,222.112 11.2407,221.563
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   18.4079,216.504 14.8243,215.125 14.466,218.689 14.8243,218.416 15.8994,218.418 16.9745,218.832 18.0496,219.657 18.7663,220.756 19.1246,222.128 19.1246,222.951
#   18.7663,224.047 18.0496,224.594 16.9745,224.592 15.8994,224.178 14.8243,223.353 14.466,222.804 14.1076,221.843
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   4.4319,181.512 5.14861,181.377 6.22369,180.556 6.22369,189.196
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   11.2407,190.304 1

# %% [markdown]
# ## Optimización con restricciones

# %% [markdown]
# [7] Utiliza un multiplicador de Lagrange para minimizar la función
# $f(x,y) = 2x+y$, sujeta a la **restricción** $x^2 + y^2 = 1$.
#
# Dibuja gráficamente lo que está pasando.
