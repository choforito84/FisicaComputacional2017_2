# %% [markdown]
# # Repaso del notebook 01

# %% [markdown]
# [0] (i) Define una función `vol_esfera` que acepta un radio y calcula el volumen de la esfera con ese radio.
#
# (ii) Utiliza tu función para calcular el volumen de la esfera con radio $\rho = 10$.
#
# (iii) Define una función `vol_cilindro` que calcula el volumen de un cilindro de radio $\rho$ y altura $\zeta$.
#
# (iv) Calcula el volumen del cilindro con radio $\rho = \frac{1}{2}$ y altura $\zeta = 10$.

# %%
function vol_esfera(ρ)
    return 4*pi*ρ^3/3
end
println(vol_esfera(10))
function vol_cilindro(ρ,ζ)
    return h*pi*ρ^2
end
println(1/2,10)
# Out:
# 4188.790204786391
# 0.510
# WARNING: Method definition vol_esfera(Any) in module Main at In[8]:2 overwritten at In[9]:2.
# WARNING: Method definition vol_cilindro(Any, Any) in module Main at In[8]:6 overwritten at In[9]:6.

# %% [markdown]
# # Creando datos y graficación

# %% [markdown]
# Una de las tareas fundamentales del cómputo científico es el manejar **datos** de todo tipo: leerlos de un archivo, o crearlos en una simulación; escribirlos a un archivo; visualizarlos, para extraer su mensaje; etc.
#
# En este notebook veremos una forma rápida de crear datos y almacenarlos.

# %% [markdown]
# ## Arreglos por comprensión

# %% [markdown]
# Tendremos que almacenar datos en algún lado. En Julia los almacenamos en arreglos.
#
# Un **arreglo** es un vector, o una lista, o una secuencia, o un conjunto (ordenado) de datos. Se puede visualizar como una pichonera con cajitas consecutivas, en las cuales se guardan los taos.

# %% [markdown]
# Julia tiene una sintaxis poderosa para crear arreglos: **arreglos por comprensión**
#
# En matemáticas, hay una notación bonita para especifar conjuntos. Por ejemplo, el conjunto de los cuadrados de los primeros diez enteros se escribe como sigue. Si notamos por $A := \{ 1, 2, \ldots, 10 \}$ los números de 1 a 10, entonces el conjunto $C$ de sus cuadrados es
#
# $$C := \{ x^2 : x \in A \}$$
#
# En Julia, ¡podemos escribir algo similar!
#
# Primero, agarremos los números de 1 al 10:

# %%
A = 1:10

# %% [markdown]
# [1] ¿Qué **tipo de objeto** es esto?

# %%
C = [i^2 for i in A]  # i^2 para i que recorre todos los valores en A

# %% [markdown]
# [2] ¿Qué tipo de objeto es este resultado?

# %% [markdown]
# Podemos leer esto como "el arreglo de $x^2$ *para* ('for') $x$ en el conjunto `A`", o "la colección [ordenada] de los cuadrados de los elementos de `A`.

# %% [markdown]
# [3] ¿Funciona si pones directamente `1:10` en lugar de `A`?

# %% [markdown]
# [4] (i) Utiliza la función `sum` para calcular la suma de estos cuadrados.
#
# (ii) Escribe una función que calcule la suma de los primeros $N$ enteros. Verifica que siempre dé el resultado analítico conocido. (Es decir, hazlo para distintos $N$ y checa si sí sea cierto.)

# %% [markdown]
# Nótese que desde Julia 0.5, podemos poner un `if` al final de la comprensión para incluir sólo ciertos valores que satisfagan cierta condición, e.g.

# %%
[i for i in A if i%3 != 0]  # % es módulo;  != es "no es igual a"
# Out:
# 7-element Array{Int64,1}:
#   1
#   2
#   4
#   5
#   7
#   8
#  10

# %%
#[1]
B=1:15
println(typeof(B))
#[2]
C=[x^2 for x in B]
println(typeof(C))
#[3]
D=[x^2 for x in 1:15]
println(D==C)
#[4]
function suma(n)
    return sum(1:n)
end
function tri(n)
    return n*(n+1)/2
end
println(tri(5))
for x in 2:64
    b=suma(x)
    a=tri(x)
    println(a==b)
end
# Out:
# UnitRange{Int64}
# Array{Int64,1}
# true
# 15.0
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true

# %% [markdown]
# # Graficación

# %% [markdown]
# [5] (i) Da una lista de los números de 1 al 100 que sean múltiplos de 3 o 5. ["O" se escribe como `||`.]
#
# (ii) Checa a ojo que esté correcto.
#
# (iii) Calcula su suma. ¿Cómo puedes verificar que la suma esté bien? Hazlo.

# %% [markdown]
# Ahora que somos capaces de producir datos interesantes, se nos antoja *visualizarlos*, es decir, graficarlos.
#
# Hay varios paquetes gráficos en Julia. El paquete `Plots` provee una interfaz común a muchos de ellos.
#
# Para utilizarlo, es necesario primero *instalar* el paquete; esto se hace una sola vez en cada instalación de Julia:

# %%
Pkg.add("Plots")

# %% [markdown]
# Recomendamos el "backend" GR:

# %%
Pkg.add("GR")

# %% [markdown]
# El paquete se tiene que cargar *en cada sesión*:

# %%
using Plots  # "using" == "usando"
gr()   # escoger el "backend" GR

# %% [markdown]
# El comando `using Plots` carga las funciones definidas en la librería para este notebook (que ya instalaste una vez con `Pkg.add`), para que ya se puedan utilizar.

# %% [markdown]
# [6] (i) Crea un arreglo `x` con números igualmente espaciados de -3 a 3 y un paso chiquito.
#
# (ii) Crea un arreglo `y` que corresponde a la función $3x^2 - 2$.
#
# (iii) Usa la función `plot` de `Plots` para graficar la función.
#
# (iv) Utiliza la ayuda de la función [`?plot` o `help(plot)`] y en la documentación del paquete u otro lado para cambiar el estilo de la gráfica para utilizar líneas rojas y puntos verdes.
#
# (v) Busca cómo agregar etiquetas a los ejes (lo cual debe hacerse en *cualquier* gráfica) y un título global, así como una leyenda.

# %%
#[5]
A=[x for x in 1:100 if x%3==0 || x%5==0 ]
println(A)
println(sum(A))


#[6]
using Plots
gr()
A=-3:.05:3
B=[(3(x^2)-2) for x in A]
plot(A,B,title="primer intento",xlabel="x",ylabel="funcion",linecolor=:green,
label="miguel",
markershape=:utriangle,
markercolor=:green)
# Out:
# [3,5,6,9,10,12,15,18,20,21,24,25,27,30,33,35,36,39,40,42,45,48,50,51,54,55,57,60,63,65,66,69,70,72,75,78,80,81,84,85,87,90,93,95,96,99,100]
# 2418
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 36.9926,369.674 596.063,369.674 596.063,23.3815 36.9926,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="36" y="23" width="560" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   140.719,364.48 140.719,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   316.528,364.48 316.528,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   492.336,364.48 492.336,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   45.3786,335.674 587.677,335.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   45.3786,214.677 587.677,214.677
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   45.3786,93.6806 587.677,93.6806
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   140.719,369.674 140.719,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   316.528,369.674 316.528,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   492.336,369.674 492.336,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,369.674 36.9926,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,335.674 45.3786,335.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,214.677 45.3786,214.677
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,93.6806 45.3786,93.6806
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 140.719, 381.674)" x="140.719" y="381.674">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 316.528, 381.674)" x="316.528" y="381.674">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 492.336, 381.674)" x="492.336" y="381.674">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7926, 340.174)" x="35.7926" y="340.174">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7926, 219.177)" x="35.7926" y="219.177">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7926, 98.1806)" x="35.7926" y="98.1806">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 316.528, 18)" x="316.528" y="18">primer intento</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 316.528, 397.6)" x="316.528" y="397.6">x</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 196.528)" x="14.4" y="196.528">funcion</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#008100; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   52.8153,33.1822 57.2105,43.9811 61.6057,54.5986 66.0009,65.0346 70.3961,75.2891 74.7914,85.362 79.1866,95.2535 83.5818,104.963 87.977,114.492 92.3722,123.839
#   96.7674,133.004 101.163,141.989 105.558,150.791 109.953,159.412 114.348,167.852 118.743,176.11 123.139,184.186 127.534,192.081 131.929,199.795 136.324,207.327
#   140.719,214.677 145.115,221.846 149.51,228.834 153.905,235.64 158.3,242.265 162.696,248.708 167.091,254.969 171.486,261.049 175.881,266.948 180.276,272.665
#   184.672,278.201 189.067,283.555 193.462,288.727 197.857,293.718 202.252,298.528 206.648,303.156 211.043,307.603 215.438,311.868 219.833,315.952 224.228,319.854
#   228.624,323.574 233.019,327.114 237.414,330.471 241.809,333.647 246.204,336.642 250.6,339.455 254.995,342.087 259.39,344.537 263.785,346.806 268.18,348.893
#   272.576,350.799 276.971,352.523 281.366,354.066 285.761,355.427 290.157,356.606 294.552,357.605 298.947,358.421 303.342,359.057 307.737,359.51 312.133,359.783
#   316.528,359.873 320.923,359.783 325.318,359.51 329.713,359.057 334.109,358.421 338.504,357.605 342.899,356.606 347.294,355.427 351.689,354.066 356.085,352.523
#   360.48,350.799 364.875,348.893 369.27,346.806 373.665,344.537 378.061,342.087 382.456,339.455 386.851,336.642 391.246,333.647 395.642,330.471 400.037,327.114
#   404.432,323.574 408.827,319.854 413.222,315.952 417.618,311.868 422.013,307.603 426.408,303.156 430.803,298.528 435.198,293.718 439.594,288.727 443.989,283.555
#   448.384,278.201 452.779,272.665 457.174,266.948 461.57,261.049 465.965,254.969 470.36,248.708 474.755,242.265 479.15,235.64 483.546,228.834 487.941,221.846
#   492.336,214.677 496.731,207.327 501.127,199.795 505.522,192.081 509.917,184.186 514.312,176.11 518.707,167.852 523.103,159.412 527.498,150.791 531.893,141.989
#   536.288,133.004 540.683,123.839 545.079,114.492 549.474,104.963 553.869,95.2535 558.264,85.362 562.659,75.2891 567.055,65.0346 571.45,54.5986 575.845,43.9811
#   580.24,33.1822
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:1" points="
#   52.8153,29.1822 48.8153,37.1822 56.8153,37.1822 52.8153,29.1822
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#008100; fill-opacity:1" points="
#   52.8153,29.9822 49.6153,36.3822 56.0153,36.3822 52.8153,29.9822
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:1" points="
#   57.2105,39.9811 53.2105,47.9811 61.2105,47.9811 57.2105,39.9811
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#008100; fill-opacity:1" points="
#   57.2105,40.7811 54.0105,47.1811 60.4105,47.1811 57.2105,40.7811
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:1" points="
#   61.6057,50.5986 57.6057,

# %% [markdown]
# ## Tiro parabólico

# %% [markdown]
# [7] (i) Haz una función que calcula la trayectoria de una partícula en tiro parabólico con una posición y velocidad iniciales dadas.
#
# (ii) Grafica distintas trayectorias con la misma rapidez inicial pero distintos ángulos iniciales. Arregla tu gráfica para que sólo muestra la parte hasta que la partícula caiga al suelo.
#
# (iii) Comprueba gráficamente para cuál ángulo se tiene el máximo **alcance**.

# %%
#[7]
function tiro(v,θ,x,y)
    A=[v*cos(θ)*t+x for t in 0:.1:50]
    B=[-9.8/2*t^2 + v*sin(θ)*t + y for t in 0:.1:50]
    return (A,B)
end
plot(tiro(60,π/4,0,0),
xlabel="x",
ylabel="y",
title="tiro parabolico",
ylims=(0,200),
label="miguel")
plot([tiro(60,i,0,0)[1] for i in π/6:.05:π/3],[tiro(60,i,0,0)[2] for i in π/6:.05:π/3],ylims=(0,200),xlims=(0,500),xlabel="x",
ylabel="y",
title="tiro parabolico")
# Out:
# WARNING: Method definition tiro(Any, Any, Any,
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 45.8815,369.674 596.063,369.674 596.063,23.3815 45.8815,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="23" width="551" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   45.8815,364.48 45.8815,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   155.918,364.48 155.918,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   265.954,364.48 265.954,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   375.99,364.48 375.99,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   486.027,364.48 486.027,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   596.063,364.48 596.063,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,369.674 587.81,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,283.101 587.81,283.101
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,196.528 587.81,196.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,109.955 587.81,109.955
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,23.3815 587.81,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,369.674 45.8815,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   155.918,369.674 155.918,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   265.954,369.674 265.954,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   375.99,369.674 375.99,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   486.027,369.674 486.027,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,369.674 596.063,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,369.674 45.8815,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,369.674 54.1342,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,283.101 54.1342,283.101
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,196.528 54.1342,196.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,109.955 54.1342,109.955
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,23.3815 54.1342,23.3815
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 45.8815, 381.674)" x="45.8815" y="381.674">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 155.918, 381.674)" x="155.918" y="381.674">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 265.954, 381.674)" x="265.954" y="381.674">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 375.99, 381.674)" x="375.99" y="381.674">300</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 486.027, 381.674)" x="486.027" y="381.674">400</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 596.063, 381.674)" x="596.063" y="381.674">500</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 374.174)" x="44.6815" y="374.174">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 287.601)" x="44.6815" y="287.601">50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 201.028)" x="44.6815" y="201.028">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 114.455)" x="44.6815" y="114.455">150</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 27.8815)" x="44.6815" y="27.8815">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 320.972, 18)" x="320.972" y="18">tiro parabolico</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 320.972, 397.6)" x="320.972" y="397.6">x</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;
# Any) in module Main at In[62]:3 overwritten at In[63]:3.

# %% [markdown]
# ## Calculando $\pi$

# %% [markdown]
# Ya estamos llegando a poder hacer cálculos útiles:
#
# [8] Una manera de calcular $\pi$ es al utilizar la [siguiente fórmula](https://en.wikipedia.org/wiki/Basel_problem):
#
# $$\sum_{n=1}^\infty \frac{1}{n^2} = \frac{\pi^2}{6}.$$
#
# (i) Fija una $N$ y calcula $\pi$ usando una suma hasta $N$. Haz de esto una función que se llama `mi_π`.
# ["π" se teclea como `\pi<TAB>`.]
#
# (ii) Ahora repite el cálculo para valores diferentes de $N$, *usando sólo lo que hemos visto en este notebook*.
#
# (iii) Grafica el resultado para los distintos valores de $N$, como función de $N$. ¿Qué observas? ¿Qué puedes agregar a tu gráfica para mostralo?
#
# (iv) ¿Cómo podrías ver qué tan rápidamente converge la suma cuando $N \to \infty$? Hazlo.

# %%
#[8]
function mi_π(n)
    return sqrt(6*(sum([1/(i^2) for i in 1:n])))
end
for n in 100:150
    println(mi_π(n))
end
function calcularpi(N)
    A=0:N
    plot((A,[mi_π(x) for x in A]),
    xlabel="N",
    ylabel="mi_pi",
    title="Cálculo de pi",
    label="calculo",
    ylims=(3.13,3.145))
    plot!((A,[pi for x in zeros(length(A))]),label="valor real")
end
# Out:
# 3.1320765318091057
# 3.132170426196346
# 3.132262485809218
# 3.132352763906585
# 3.132441311705781
# 3.1325281784795025
# 3.1326134116472333
# 3.13269705686156
# 3.132779158089708
# 3.1328597576906025
# 3.13293889648774
# 3.1330166138381332
# 3.1330929476975773
# 3.133167934682455
# 3.133241610128303
# 3.133314008145334
# 3.1333851616710904
# 3.133455102520408
# 3.1335238614328498
# 3.1335914681177504
# 3.133657951297018
# 3.133723338745819
# 3.133787657331267
# 3.1338509330492315
# 3.133913191059368
# 3.1339744557184748
# 3.1340347506122628
# 3.1340940985856296
# 3.1341525217715187
# 3.1342100416184397
# 3.1342666789167226
# 3.13432245382357
# 3.1343773858869777
# 3.134431494068577
# 3.1344847967654537
# 3.1345373118310085
# 3.1345890565948884
# 3.134640047882057
# 3.134690302031031
# 3.134739834911337
# 3.1347886619402168
# 3.134836798098628
# 3.1348842579465663
# 3.1349310556377503
# 3.1349772049336933
# 3.135022719217195
# 3.1350676115052796
# 3.1351118944616094
# 3.135155580408392
# 3.135198681337813
# 3.135241208923012
# WARNING: Method definition mi_π(Any) in module Main at In[41]:3 overwritten at In[42]:3.
# calcularpi (generic function with 1 method)

# %%
calcularpi(1000)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 63.6592,369.674 596.063,369.674 596.063,23.3815 63.6592,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="63" y="23" width="533" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   63.6592,364.48 63.6592,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   170.14,364.48 170.14,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   276.621,364.48 276.621,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   383.101,364.48 383.101,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   489.582,364.48 489.582,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   596.063,364.48 596.063,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   71.6453,369.674 588.077,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   71.6453,254.243 588.077,254.243
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   71.6453,138.812 588.077,138.812
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   71.6453,23.3815 588.077,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   63.6592,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   63.6592,369.674 63.6592,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   170.14,369.674 170.14,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   276.621,369.674 276.621,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   383.101,369.674 383.101,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   489.582,369.674 489.582,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,369.674 596.063,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   63.6592,369.674 63.6592,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   63.6592,369.674 71.6453,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   63.6592,254.243 71.6453,254.243
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   63.6592,138.812 71.6453,138.812
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   63.6592,23.3815 71.6453,23.3815
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 63.6592, 381.674)" x="63.6592" y="381.674">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 170.14, 381.674)" x="170.14" y="381.674">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 276.621, 381.674)" x="276.621" y="381.674">400</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 383.101, 381.674)" x="383.101" y="381.674">600</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 489.582, 381.674)" x="489.582" y="381.674">800</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 596.063, 381.674)" x="596.063" y="381.674">1000</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 62.4592, 374.174)" x="62.4592" y="374.174">3.130</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 62.4592, 258.743)" x="62.4592" y="258.743">3.135</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 62.4592, 143.312)" x="62.4592" y="143.312">3.140</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 62.4592, 27.8815)" x="62.4592" y="27.8815">3.145</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 329.861, 18)" x="329.861" y="18">Cálculo de pi</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 329.861, 397.6)" x="329.861" y="397.6">N</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:start;" transform="rotate(-90, 14.7312, 210.275)" x="14.7312" y="210.275">mi</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:14; text-anchor:start;" transform="rotate(-90, 19.4164, 193.082)" x="19.4164" y="193.082">pi</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   63.6592,72629.4 64.1916,16080.1 64.724,9405.31 65.2564,6655.16 65.7888,5157.45 66.3212,4216.12 66.8537,3569.96 67.3861,3

# %%
plot([tiro(60,i,0,0)[1] for i in π/6:.1:π/3],[tiro(60,i,0,0)[2] for i in π/6:.1:π/3],ylims=(0,200))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 30.6037,384.952 596.063,384.952 596.063,3.93701 30.6037,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="30" y="3" width="566" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   30.6037,379.237 30.6037,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   139.426,379.237 139.426,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   248.249,379.237 248.249,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   357.072,379.237 357.072,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   465.894,379.237 465.894,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   574.717,379.237 574.717,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,384.952 587.581,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,289.698 587.581,289.698
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,194.444 587.581,194.444
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,99.1907 587.581,99.1907
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,3.93701 587.581,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   139.426,384.952 139.426,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   248.249,384.952 248.249,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   357.072,384.952 357.072,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   465.894,384.952 465.894,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   574.717,384.952 574.717,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 39.0856,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,289.698 39.0856,289.698
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,194.444 39.0856,194.444
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,99.1907 39.0856,99.1907
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,3.93701 39.0856,3.93701
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 30.6037, 396.952)" x="30.6037" y="396.952">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 139.426, 396.952)" x="139.426" y="396.952">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 248.249, 396.952)" x="248.249" y="396.952">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 357.072, 396.952)" x="357.072" y="396.952">300</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 465.894, 396.952)" x="465.894" y="396.952">400</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 574.717, 396.952)" x="574.717" y="396.952">500</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 389.452)" x="29.4037" y="389.452">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 294.198)" x="29.4037" y="294.198">50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 198.944)" x="29.4037" y="198.944">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 103.691)" x="29.4037" y="103.691">150</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 8.43701)" x="29.4037" y="8.43701">200</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 36.2583,379.33 41.9129,373.895 47.5675,368.646 53.222,363.585 58.8766,358.709 64.5312,354.021 70.1858,349.519 75.8404,345.204 81.495,341.076
#   87.1496,337.135 92.8042,333.38 98.4588,329.811 104.113,326.43 109.768,323.235 115.423,320.227 121.077,317.406 126.732,314.771 132.386,312.323 138.041,310.062
#   143.696,307.987 149.35,306.099 155.005,304.398 160.659,302.883 166.314,301.555 171.969,300.414 177.623,299.46 183.278,298.692 188.932,298.111 194.587,297.717
#   200.241,297.509 205.
