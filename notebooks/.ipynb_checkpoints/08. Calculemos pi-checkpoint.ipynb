# %% [markdown]
# # ¡Calculemos $\pi$ de muchas maneras!

# %% [markdown]
# ¡Hoy es el día de $\pi$! La fecha de hoy es el 14 de marzo del 2017, o sea 3-14, los cuales son los primeros dígitos de $\pi$, y por lo tanto se ha designado como [el día de $\pi$](https://en.wikipedia.org/wiki/Pi_Day).
#
# En honor a este evento importante, veremos unos métodos para calcular $\pi$ usando distintas técnicas numéricas. Algunas serán aplicaciones de técnicas que ya vimos, mientras que otras serán un avance de técnicas por verse más adelante en el curso.
#
# En cada caso, las metas son las siguientes, como en casi cualquier problema de cómputo científico:
#
# - Entender el problema matemático y su relación con $\pi$ (es decir, cómo ocurre $\pi$ como solución al problema matemático).
# - Desarrollar e implementar un método numérico correspondiente.
# - Entender cuáles son las propiedades de convergencia del método e intentar sacar el mayor precisión (número de dígitos de $\pi$) posible.

# %% [markdown]
# ## $\pi$ como una raíz

# %% [markdown]
# **[1]** ¿Para cuál función trigonométrica es $\pi$ una raíz? Usa esto para calcular $\pi$ con el mayor número de dígitos posible. (¿Cuál método numérico podríamos utilizar para calcular la función trigonométrica si lo tuviéramos que hacer nosotros? Hazlo si tienes ganas.)

# %%
using Plots,Interact
gr()
# Out:
# <div id="interact-js-shim">
#     <script charset="utf-8">
# (function (IPython, $, _, MathJax) {
#     $.event.special.destroyed = {
# 	remove: function(o) {
# 	    if (o.handler) {
# 		o.handler.apply(this, arguments)
# 	    }
# 	}
#     }
#
#     var OutputArea = IPython.version >= "4.0.0" ? require("notebook/js/outputarea").OutputArea : IPython.OutputArea;
#
#     var redrawValue = function (container, type, val) {
# 	var selector = $("<div/>");
# 	var oa = new OutputArea(_.extend(selector, {
# 	    selector: selector,
# 	    prompt_area: true,
# 	    events: IPython.events,
# 	    keyboard_manager: IPython.keyboard_manager
# 	})); // Hack to work with IPython 2.1.0
#
# 	switch (type) {
# 	case "image/png":
#             var _src = 'data:' + type + ';base64,' + val;
# 	    $(container).find("img").attr('src', _src);
# 	    break;
# 	case "text/latex":
# 		if (MathJax){
# 			var math = MathJax.Hub.getAllJax(container)[0];
# 			MathJax.Hub.Queue(["Text", math, val.replace(/^\${1,2}|\${1,2}$/g, '')]);
# 			break;
# 		}
# 	default:
# 	    var toinsert = OutputArea.append_map[type].apply(
# 		oa, [val, {}, selector]
# 	    );
# 	    $(container).empty().append(toinsert.contents());
# 	    selector.remove();
# 	}
#     }
#
#
#     $(document).ready(function() {
# 	function initComm(evt, data) {
# 	    var comm_manager = data.kernel.comm_manager;
#         //_.extend(comm_manager.targets, require("widgets/js/widget"))
# 	    comm_manager.register_target("Signal", function (comm) {
#             comm.on_msg(function (msg) {
#                 var val = msg.content.data.value;
#                 $(".signal-" + comm.comm_id).each(function() {
#                 var type = $(this).data("type");
#                 if (typeof(val[type]) !== "undefined" && val[type] !== null) {
#                     redrawValue(this, type, val[type], type);
#                 }
#                 });
#                 delete val;
#                 delete msg.content.data.value;
#             });
# 	    });
#
# 	    // coordingate with Comm and redraw Signals
# 	    // XXX: Test using Reactive here to improve performance
# 	    $([IPython.events]).on(
# 		'output_appended.OutputArea', function (event, type, value, md, toinsert) {
# 		    if (md && md.reactive) {
#                 // console.log(md.comm_id);
#                 toinsert.addClass("signal-" + md.comm_id);
#                 toinsert.data("type", type);
#                 // Signal back indicating the mimetype required
#                 var comm_manager = IPython.notebook.kernel.comm_manager;
#                 var comm = comm_manager.comms[md.comm_id];
#                 comm.then(function (c) {
#                     c.send({action: "subscribe_mime",
#                        mime: type});
#                     toinsert.bind("destroyed", function() {
#                         c.send({action: "unsubscribe_mime",
#                                mime: type});
#                     });
#                 })
# 		    }
# 	    });
# 	}
#
# 	try {
# 	    // try to initialize right away. otherwise, wait on the status_started event.
# 	    initComm(undefined, IPython.notebook);
# 	} catch (e) {
# 	    $([IPython.events]).on('kernel_created.Kernel kernel_created.Session', initComm);
# 	}
#     });
# })(IPython, jQuery, _, MathJax);
# </script>
#     <script>
#         window.interactLoadedFlag = true
#        $("#interact-js-shim").bind("destroyed", function () {
#            if (window.interactLoadedFlag) {
#                console.warn("JavaScript required by Interact will be removed if you remove this cell or run using Interact more than once.")
#            }
#        })
#        $([IPython.events]).on("kernel_starting.Kernel kernel_restarting.Kernel", function () { window.interactLoadedFlag = false })
#    </script>
# </div>
# Plots.GRBackend()

# %%
#[1]
function derivada(f :: Function, a:: Number,h :: Number = 1e-8)
    return ((f(a+h)-f(a-h))/(2h))
end
function newton(f :: Function,x0 :: Number;tol=1e-15,test=false,list=false)
    x=[]
    push!(x,x0)
    i=1
    while abs(f(x[i]))>tol
        if test==true
            @show (x[i],f(x[i]),derivada(f,x[i]))
        end
        if i==10000
            return "fail"
        end
        push!(x,x[i]-(f(x[i])/derivada(f,x[i])))
        i=i+1
    end
    if list==true
        return x
    else
        return x[end]
    end
end
# Out:
# newton (generic function with 1 method)

# %%
big(newton(sin,3,tol=1e-15))
# Out:
# 3.141592653589793115997963468544185161590576171875000000000000000000000000000000

# %% [markdown]
# ## $\pi$ y el círculo

# %% [markdown]
# **[2]** (i) ¿Cuál es el área de un disco de radio $r$? Así, ¿cuál es el área de un disco de radio $1$?
#
# (ii) ¿Cuál es la condición para que un punto $(x, y)$ caiga adentro de un disco de radio $r$?
#
# (iii) Usemos el método de "pintar" como sigue. Considera una caja cuadrada que contenga el disco. Divídelo en cuadritos [pista: usar la función `linspace` para dividirlo en $L$ partes en la dirección $x$ y $L$ en la dirección $y$, por separado]. Para cada cuadrito, aproxima si el cae o no adentro del disco al checar si su punto céntrico lo hace. Dibuja el resultado, con un calor para las cajas que caigan adentro, y otro para los que caigan afuera.
#
# (iv) Así, calcula el área aproximada del disco. ¿A qué operación matemática corresponde el cálculo de un área de esta forma? Utiliza el resultado para calcular $\pi$.
#
# (v) Si cambias $N$, ¿cuánto trabajo tendrás que hacer? Estima (analíticamente) la **complejidad computacional**, es decir, el número (aproximado) de operaciones como función de $N$. ¿Cómo puedes estimar el error que cometerás para el área?
#
# (vi) Calcula numéricamente el error (desde el valor exacto de $\pi$) en función de $L$. ¿Cómo converge?

# %% [markdown]
# ### [2]
#
# i) Para un círculo de radio r, el área es $ A = \pi r^2$. En particular, cuando $r=1$,$A=\pi$
#
# ii) Para que un punto $(x,y)$ caiga en un radio, debe de estar a una distancia $r$ del origen, es decir, se debe cumplir que $\sqrt{x^2 + y^2} = r$

# %%
#[2]
function checar(x::Number,y::Number,r::Number=1)
    if sqrt(x^2 + y^2)<=r
        return 1
    else
        return 0
    end
end
function pintar(L::Int64)
    X=linspace(-1,1,L+1)
    Y=linspace(-1,1,L+1)
    M=[checar(x,y) for x in X, y in Y]
    return M
end
# Out:
# WARNING: Method definition checar(
# pintar (generic function with 1 method)
# Number, Number) in module Main at In[4]:3 overwritten at In[20]:3.
# WARNING: Method definition checar(Number, Number, Number) in module Main at In[4]:3 overwritten at In[20]:3.
# WARNING: Method definition pintar(Int64) in module Main at In[4]:10 overwritten at In[20]:10.

# %%
heatmap(pintar(600),color=:blues)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 30.6037,384.952 596.063,384.952 596.063,3.93701 30.6037,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="30" y="3" width="506" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   198.248,379.237 198.248,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   366.734,379.237 366.734,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   535.221,379.237 535.221,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   38.1856,258.582 528.481,258.582
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   38.1856,131.577 528.481,131.577
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   38.1856,4.57203 528.481,4.57203
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 536.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   198.248,384.952 198.248,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   366.734,384.952 366.734,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   535.221,384.952 535.221,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,258.582 38.1856,258.582
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,131.577 38.1856,131.577
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,4.57203 38.1856,4.57203
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 198.248, 396.952)" x="198.248" y="396.952">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 366.734, 396.952)" x="366.734" y="396.952">400</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 535.221, 396.952)" x="535.221" y="396.952">600</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 263.082)" x="29.4037" y="263.082">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 136.077)" x="29.4037" y="136.077">400</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 9.07203)" x="29.4037" y="9.07203">600</text>
# </g>
# <g clip-path="url(#clip02)">
# <image width="505" height="381" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAfkAAAF9CAYAAAAHlxEqAAAMHElEQVR4nO3azXXjxhaFUbSXg3E+
# HnZ8HiofRdBp9Bv4yS21xB+QhcK9p/aOgAsk6+MB+O3l9cfPDQCI8+fZLwC47O+//jn7Jdzl5fX7
# 2S8B+MI3Sx6O1SXUZ/EDAY4j8jCQoI8h/DCGyMOdBLwWPwTgNpGHC0S9F9GHz0SepQn5GvwAYFUi
# Tzwh5xo/AEgm8kQSdh4h+KQRedoTdI4k/HQm8rQk7JxB8OlG5ClP0KlM+KlM5ClL3OlE7KlI5ClD
# 1Eki+lQg8pxC0FmR8DObyDOVuIPYM4/Iczhhh8sEnyOJPIcQdthP8BlN5BlG2GEcwWcEkedp4g7H
# EXueIfI8RNhhPsFnL5HnLqIO9Yg+t/xx9gugPoGHmnw3ucWS5xMHB/Rl3fOeJc8HAg+9+Q7zniWP
# QwGCWfZrE/lFCTusR/DXI/KLEXdA7Nch8gsQduASwc/mj3fhBB64xhmRzZIP5EsLPMqyz2LJhxF4
# 4BnOkCyWfAhfTGA0q74/kW9M2IFZBL8nt+ubEnhgJmdOT5Z8I75kQBWWfQ+WfBMCD1TiTOrBki/O
# Fwmozqqvy5IvTOCBDpxVdVnyxfiyAN1Z9nVY8oUIPJDAWVaHJV+ALwSQyqo/l8ifSNyBVYj9Odyu
# B4BQlvxk1juwOqt+Hkt+IoEHcBbOJPKT+FAD/OJMnMPt+gP5EAPcxy38Y1jyBxF4gPs5M48h8gfw
# YQXYz9k5nsgP5kMK8Dhn6FieyQ/igwkwluf0zxP5Jwg7wByC/xi36wEglCX/AAse4BwW/T6W/E4C
4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 38.3022, 175.179)" x="38.3022" y="175.179">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 51.4815, 168.326)" x="51.4815" y="168.326">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 57.1052, 168.326)" x="57.1052" y="168.326">3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 38.3022, 82.024)" x="38.3022" y="82.024">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 51.4815, 75.1714)" x="51.4815" y="75.1714">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 57.1052, 75.1714)" x="57.1052" y="75.1714">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 329.861, 18)" x="329.861" y="18">tasa de convergencia</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 329.861, 397.6)" x="329.861" y="397.6">n</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 196.528)" x="14.4" y="196.528">area(n)</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="63.6592" cy="113.236" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="63.6592" cy="113.236" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="67.1786" cy="55.4889" r="3"/>
# <circle clip-path="url(#clip02)" styl

# %% [markdown]
# ### [2]
#
# v) Debido a que, si dividimos cada lado del cuadrado de lado $2$ que tiene la circunferencia de radio $1$ inscrita en $n$ pedazos, debemos de checar para $n^2$ puntos si es que estos están dentro del círculo y posteriormente, dado el número de cuadrados dentro, debe de multiplicar por el área de cada uno (que es igual para todos, dado que las particiones de los lados son regulares) y sumar. Podemos concluir que la complejidad de nuestro algoritmo será $\mathcal{O}(n^2)$
#
# vi) Claramente, esta es una aproximiación de Pi mediante una integral de superficie para la función característica del círculo de radio 1 sobre el intervalo de $[-1,1]\times[-1,1] \subset \mathbb{R}^2  $

# %% [markdown]
# **[3]** (i) ¿Cuál es la circunferencia de un círculo de radio $r$?
#
# (ii) Usa el método de "pintar" pero sólo pintando los cuadritos que están "en el círculo". [Pista: Puedes aproximar esto diciendo que el centro del cuadrito esté dentro de una cierta tolerancia de la frontera. ¿Cuál tolerancia sería razonable utilizar?]
#
# (iii) Así, calcula el valor de $\pi$ en función de $L$, y encuentra la tasa de convergencia.

# %%
#[3]
function checar2(x::Number,y::Number,r::Number =1;tol::Number=1e-2)
    if abs(sqrt(x^2 + y^2)-r)<=tol
        return 1
    else
        return 0
    end
end
function pintar2(L::Int64;tol::Number=1e-2, test=false)
    X=linspace(-1,1,L+1)
    Y=linspace(-1,1,L+1)
    M=[checar2(x,y;tol=tol) for x in X, y in Y]
    return M
end
function area2(L::Int64,t::Number=1e-2)
    return ((sum(pintar2(L,tol=t)*((2/L)^2)))/(4*t))
end
# Out:
# area2 (generic function with 2 methods)

# %%
heatmap(pintar2(6000))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.4926,384.952 596.063,384.952 596.063,3.93701 39.4926,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="3" width="497" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   204.933,379.237 204.933,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   370.457,379.237 370.457,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   535.98,379.237 535.98,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   46.9411,258.01 528.614,258.01
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   46.9411,131.005 528.614,131.005
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   46.9411,4.00051 528.614,4.00051
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,384.952 536.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   204.933,384.952 204.933,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   370.457,384.952 370.457,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   535.98,384.952 535.98,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,384.952 39.4926,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,258.01 46.9411,258.01
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,131.005 46.9411,131.005
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,4.00051 46.9411,4.00051
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 204.933, 396.952)" x="204.933" y="396.952">2000</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 370.457, 396.952)" x="370.457" y="396.952">4000</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 535.98, 396.952)" x="535.98" y="396.952">6000</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.2926, 262.51)" x="38.2926" y="262.51">2000</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.2926, 135.505)" x="38.2926" y="135.505">4000</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.2926, 8.50051)" x="38.2926" y="8.50051">6000</text>
# </g>
# <g clip-path="url(#clip02)">
# <image width="496" height="381" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAA

# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 12.8259,384.952 596.063,384.952 596.063,3.93701 12.8259,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="12" y="3" width="584" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   200.092,379.237 200.092,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   389.824,379.237 389.824,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   579.556,379.237 579.556,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   21.5745,374.172 587.314,374.172
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   21.5745,293.017 587.314,293.017
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   21.5745,211.862 587.314,211.862
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   21.5745,130.707 587.314,130.707
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   21.5745,49.5525 587.314,49.5525
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   200.092,384.952 200.092,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   389.824,384.952 389.824,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   579.556,384.952 579.556,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,384.952 12.8259,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,374.172 21.5745,374.172
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,293.017 21.5745,293.017
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,211.862 21.5745,211.862
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,130.707 21.5745,130.707
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,49.5525 21.5745,49.5525
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 200.092, 396.952)" x="200.092" y="396.952">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 389.824, 396.952)" x="389.824" y="396.952">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 579.556, 396.952)" x="579.556" y="396.952">300</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 11.6259, 378.672)" x="11.6259" y="378.672">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 11.6259, 297.517)" x="11.6259" y="297.517">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 11.6259, 216.362)" x="11.6259" y="216.362">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 11.6259, 135.207)" x="11.6259" y="135.207">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 11.6259, 54.0525)" x="11.6259" y="54.0525">8</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="29.3326" cy="14.7204" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="29.3326" cy="14.7204" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="31.2299" cy="233.369" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="31.2299" cy="233.369" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="33.1273" cy="359.41" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="33.1273" cy="359.41" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="35.0246" cy="117.485" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="35.0246" cy="117.485" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="36.9219" cy="329.506" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="36.9219" cy="329.506" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="38.8192" cy="357.375" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="38.8192" cy="357.375" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="40.7165" cy="184.639" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="40.7165" cy="184.639" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="42.6139" cy="277" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="42.6139" cy="277" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="44.5112" cy="251.172" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="44.5112" cy="251.172" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="46.4085" cy="336.617" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="46.4085" cy="336.617" r="2"/>
# <circle clip-path="url(#cli

# %% [markdown]
# ## $\pi$ como una integral

# %% [markdown]
# **[4]** (i) Pensando de nuevo en el disco de radio $r$, enfoquémonos en el cuadrante positivo ($x \ge 0$ y $y \ge 0$).
# Escribe el área del cuadrante como una integral sobre $x$. [Pista: dada $x$, cuál es el valor de $y$ correspondiente sobre el círculo?
#
# (ii) Divide el intervalo en $x$ en $L$ partes y utiliza una integral de Riemann para aproximar el área, y así calcular $\pi$. [Pista: ¿cuál es un valor del radio $r$ útil?]
#
# (iii) ¿Cómo converge en función de $L$ el error? Dibújalo.

# %% [markdown]
# ### [4]
#
# El area de un cuadrante del círculo puede entenderse como la siguiente integral:
#
# $$\frac{\pi r^2}{4} = \int_0^r \sqrt{r^2-x^2} dx$$

# %%
function circulo(x::Number,r::Number)
    return sqrt(r^2 - x^2)
end
function integral(L::Int64,r::Number)
    X=linspace(0,r,L+1)
    total=0
    for i in 2:length(X)
        total+=(X[i]-X[i-1])*circulo(X[i],r)
    end
    return total*4
end
# Out:
# integral (generic function with 1 method)

# %%
integral(70000,1)
# Out:
# 3.1415640186641736

# %%
A=20:200
scatter(A,[abs(integral(x,1)-pi) for x in A],xscale=:log10,yscale=:log10,title="tasa de convergencia",xlabel="n",ylabel="integral(n)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 81.437,369.674 596.063,369.674 596.063,23.3815 81.437,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="81" y="23" width="515" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   441.145,364.48 441.145,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   89.1564,208.438 588.344,208.438
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   89.1564,41.2895 588.344,41.2895
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   81.437,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   441.145,369.674 441.145,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   81.437,369.674 81.437,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   81.437,208.438 89.1564,208.438
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   81.437,41.2895 89.1564,41.2895
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 431.878, 386.626)" x="431.878" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 445.058, 379.773)" x="445.058" y="379.773">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 48.0489, 214.37)" x="48.0489" y="214.37">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 61.2281, 207.518)" x="61.2281" y="207.518">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 66.8518, 207.518)" x="66.8518" y="207.518">1.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 48.0489, 47.2214)" x="48.0489" y="47.2214">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 61.2281, 40.3688)" x="61.2281" y="40.3688">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 66.8518, 40.3688)" x="66.8518" y="40.3688">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 338.75, 18)" x="338.75" y="18">tasa de convergencia</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 338.75, 397.6)" x="338.75" y="397.6">n</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 196.528)" x="14.4" y="196.528">integral(n)</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="81.437" cy="23.3815" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="81.437" cy="23.3815" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="92.3416" cy="30.8704" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="92.3416" cy="30.8704" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="102.739" cy="38.0029" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="102.739" cy="38.0029" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="112.674" cy="44.8111" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="112.674" cy="44.8111" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="122.186" cy="51.323" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="122.186" cy="51.323" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="131.309" cy="57.5632" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="131.309" cy="57.5632" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="140.075" cy="63.5534" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="140.075" cy="63.5534" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="148.51" cy="69.3126" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="148.51" cy="69.3126" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="156.638" cy="74.8579" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="156.638" cy="74.8579" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="164.481" cy="80.2046" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="164.481" cy="80.2046" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="172.058" cy="85.3662" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="172.058" cy="85.3662" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="179.387" cy="90.3552" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="179.387" cy="90.3552" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="186.482" cy="95.1825" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="186.482" cy="95.1825" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="193.36" cy="99.8583" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="193.36" cy="99.8583" r="2"/>
# <circle clip-path="url(#clip02)" style="fill

# %% [markdown]
# ## Un método azaroso: tirar dardos

# %% [markdown]
# **[5]** Más adelante en el curso, veremos que los **métodos Monte Carlo**, o métodos azarosos, pueden ser útiles. Veremos un primer ejemplo aquí.
#
# Pensemos de nuevo en el disco, digamos de radio $1$.
#
# (i) Tiremos dardos a un cuadrado que contenga el disco, digamos $[-1,1] \times [-1,1]$. Para hacerlo, utiliza la función `rand`, que genera números aleatorios distribuidos uniformemente entre $0$ y $1$. ¿Cómo puedes generar números uniformemente entre $-1$ y $1$?
#
# (ii) Genera $N$ puntos al azar en el cuadrado. Dibuja los puntos que caigan adentro del disco en un color, y los que caigan afuera en otro color.
#
# (iii) ¿Cuál será la relación entre las áreas y los números de puntos correspondientes? Así, estima el valor de $\pi$.
#
# (iv) Para cada valor de $N$, repite el experimento varias veces y saca un promedio.
#
# (v) Dibuja el error de este promedio desde el valor exacto de $\pi$, como función de $N$. ¿Cómo converge?

# %%
function montecarlov(N::Int64)
    A=(rand(N,2)*2 -1)
    SI=transpose(hcat([A[i,:] for i in 1:N if checar(A[i,1],A[i,2])==1]...))
    NO=transpose(hcat([A[i,:] for i in 1:N if checar(A[i,1],A[i,2])!=1]...))
    scatter(SI[:,1],SI[:,2],color=:green,shape=:circle,markersize=8,label="Circulo")
    scatter!(NO[:,1],NO[:,2],color=:black,shape=:square,label="fuera",markersize=8)
end
# Out:
# montecarlov (generic function with 1 method)

# %%
montecarlov(100)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
#
r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="78.7273" cy="314.31" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="81.2386" cy="321.4" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="81.2386" cy="321.4" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="83.7499" cy="237.503" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="83.7499" cy="237.503" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="86.2613" cy="312.619" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="86.2613" cy="312.619" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="88.7726" cy="252.524" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="88.7726" cy="252.524" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="91.284" cy="314.054" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="91.284" cy="314.054" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="93.7953" cy="180.363" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="93.7953" cy="180.363" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="96.3066" cy="302.409" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="96.3066" cy="302.409" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="98.818" cy="213.236" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="98.818" cy="213.236" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="101.329" cy="340.909" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="101.329" cy="340.909" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="103.841" cy="115.485" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="103.841" cy="115.485" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="106.352" cy="158.601" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1"

# %% [markdown]
# ## Series para $\pi$

# %% [markdown]
# **[6]** En uno de los primeros notebooks, vimos una serie infinita para $\pi$, pero converge muy lento. Implementa algunos de estos algoritmos modernos y eficientes para calcular $\pi$ y encuentra numéricamente cómo convergen [utiliza `BigFloat` cuando sea necesario]:
#
# https://en.wikipedia.org/wiki/Approximations_of_%CF%80#Development_of_efficient_formulae

# %%
#[6]
#Algoritmo de Gauss-Legendre
function gauss_legendre(N::Int64)
    a=big(1)
    b=big(1/sqrt(2))
    t=big(1/4)
    p=big(1)
    total=[]
    for i in 1:N
        (a,b,t,p)=((a+b)/2,sqrt(a*b),t-p*((a-(a+b)/2)^2),2p)
        push!(total,big(((a+b)^2)/(4*t)))
    end
    return total
end
# Out:
# WARNING: Method definition gauss_legendre(Int64
# gauss_legendre (generic function with 1 method)
# ) in module Main at In[96]:4 overwritten at In[99]:4.

# %%
A=1:50
scatter(A,[abs(pi-x) for x in gauss_legendre(50)],title="tasa de convergencia",ylabel="gauss_ legendre",xlabel="n",xscale=:log10,yscale=:log10)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 72.5481,369.674 596.063,369.674 596.063,23.3815 72.5481,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="72" y="23" width="524" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   72.5481,364.48 72.5481,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   226.616,364.48 226.616,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   380.685,364.48 380.685,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   534.753,364.48 534.753,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,345.642 588.21,345.642
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,211.432 588.21,211.432
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,77.2209 588.21,77.2209
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,369.674 72.5481,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   226.616,369.674 226.616,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   380.685,369.674 380.685,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   534.753,369.674 534.753,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,369.674 72.5481,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,345.642 80.4008,345.642
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,211.432 80.4008,211.432
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,77.2209 80.4008,77.2209
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 59.2659, 386.626)" x="59.2659" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 72.4452, 379.773)" x="72.4452" y="379.773">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 213.334, 386.626)" x="213.334" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 226.513, 379.773)" x="226.513" y="379.773">0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 367.403, 386.626)" x="367.403" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 380.582, 379.773)" x="380.582" y="379.773">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 521.471, 386.626)" x="521.471" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 534.65, 379.773)" x="534.65" y="379.773">1.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 41.837, 351.574)" x="41.837" y="351.574">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 55.0163, 344.722)" x="55.0163" y="344.722">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.64, 344.722)" x="60.64" y="344.722">15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 41.837, 217.364)" x="41.837" y="217.364">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 55.0163, 210.511)" x="55.0163" y="210.511">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.64, 210.511)" x="60.64" y="210.511">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 47.1911, 83.1528)" x="47.1911" y="83.1528">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.3703, 76.3002)" x="60.3703" y="76.3002">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 65.994, 76.3002)" x="65.994" y="76.3002">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 334.306, 18)" x="334.306" y="18">tasa de convergencia</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 334.306, 397.6)" x="334.306" y="397.6">n</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opac

# %%
x
# Out:
# 6
