# %% [markdown]
# # Raíces de funciones uni-dimensionales

# %% [markdown]
# En este notebook, investigaremos algunos métodos para encontrar **raíces** de funciones uni-dimensionales, usando métodos iterativos. Esto es un problema que ocurre por todos lados en la física, por ejemplo para el pozo cuadrado en mecánica cuántica, o para encontrar el valor máximo de una función.
#
# Recuerda que $x^*$ es una raíz (o cero) de la función $f$ si $f(x^*) = 0$. Como sabemos, en general las raíces de una función no se pueden encontrar de manera analítica, excepto para funciones $f$ que sean polinomios de grado $\le 4$.
#
# Por lo tanto, para encontrar raíces tendremos que utilizar algoritmos iterativos.
# Recuerda que un algoritmo iterativo tiene la forma general
#
# $$x_{n+1} := f(x_n),$$
#
# y consiste en comenzar en un punto inicial $x_0$ y generar una secuencia $x_1 = f(x_0)$; $x_2 = f(x_1)$, etc.
# Si diseñamos correctamente el algoritmo, la esperanza es que la secuencia $(x_n)_{n=1}^\infty$ converja a alguna raíz  $x^*$ con $f(x_\infty) = 0$, es decir que $f(x_n) \to 0$ cuando $n \to \infty$.

# %% [markdown]
# Dado que no podemos llevar a cabo la iteración un número infinito de veces, se corta la iteración después de un cierto número de pasos, para dar una solución *aproximada*, que se encuentra dentro de cierta *tolerancia* del resultado teórico exacto $x^*$. Por lo tanto, cualquier algoritmo iterativo requiere una condición de terminación.

# %% [markdown]
# # Raíces de funciones: Bisección

# %% [markdown]
# Un primer método para encontrar una raíz es el **método de bisección**.
# Dada una función continua $f$, una condición suficiente (pero no necesaria) para que *exista* una raiz en un intervalo dado $[a, b]$ es que $F$ cambie de signo en el intervalo, es decir, que $f(a)$ y $f(b)$ tengan signos opuestos. Si ocurre esto, entonces el teorema del valor intermedio nos dice que se sigue que $f$ sí tiene al menos una raíz en $[a, b]$.

# %% [markdown]
# [1] La idea del método de bisección es de adivinar que el punto medio del intervalo $[a, b]$ sea una primera aproximación para la raíz. Escribamos una función que implemente bisección, que toma como argumento la función $f$ y el intervalo $[a, b]$.
#
# (i) Define $c$ como el punto medio del intervalo.
#
# (ii) Esto divide el intervalo original en dos partes. Es posible (aunque improbable) que $c$ ya es la raíz, en cuyo caso ya podemos terminar la función y regresar la raíz que hemos encontrado. ¿Cómo se checa si ya es la raíz? Si no, ¿cómo podemos saber en cuál de los dos sub-intervalos cae la raíz? Impleméntalo.
#
# [Pista: Tal vez querrás definir una función `signo` que toma un argumento `x` y regresa $0$ si `x` es igual a `0`, regresa `1` si `x` es mayor que cero, y regresa `-1` si `x` es menor que cero.]
#
# (iii) Repite estos pasos hasta que encuentres la raíz con cierta tolerancia.
#
# [2] Aplica tu función para encontrar *las dos* raíces cuadradas de $2$. Para hacerlo, tendrás que escoger (a mano) intervalos iniciales a mano cumplan con la condición de cambio de signo.
#
# [3] (i) Haz una versión nueva de tu función que regresa un arreglo de todos los iterados `x`. Utiliza un método gráfico para estimar la tasa de convergencia del método hacia la raíz.
#
# (ii) Haz una versión nueva de tu función que escoge otro punto (que no sea el punto medio) entre $a$ y $b$, escogido de forma lineal entre $a$ y $b$ con un parámetro $\alpha$, tal que $\alpha = 0$ da $a$ y $\alpha=1$ da $b$. ¿Cambia la tasa de convergencia?

# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
#[1]
function biseccion1(f::Function,a,b,test=0)
    c=(b+a)/2
    i=1
    while abs(f(c))>1e-10
        if test==1          #codigo extra para testear la función
            println("ciclo")
            @show (c,f(c),f(a),f(b))
        end
        if f(c)*f(a)<0
            if test==1
                println("ac")
            end
            b=c
            c=(a+b)/2
            elseif f(c)*f(b)<0
            if test==1
                println("bc")
            end
            a=c
            c=(a+b)/2
        end
        if i==1000
            return "fail"
        end
        i=i+1
    end
    return c
end
# Out:
# biseccion1 (generic function with 2 methods)

# %%
#[2]
function f(x)
    return x^2 -2
end
println(biseccion1(f,1,2))
println(biseccion1(f,-2,-1))
# Out:
# 1.4142135623842478
# -1.4142135623842478

# %%
#[3]
function biseccion2(f::Function,a,b,test=0)
    c=(b+a)/2
    l=[f(c)]
    i=1
    while abs(f(c))>1e-10
        if test==1          #codigo extra para testear la función
            @show (c,f(c),f(a),f(b))
        end
        if f(c)*f(a)<0
            if test==1
                println("ac")
            end
            b=c
            c=(a+b)/2
            elseif f(c)*f(b)<0
            if test==1
                println("bc")
            end
            a=c
            c=(a+b)/2
        end
        if i==1000
            return "fail"
        end
        i=i+1
        push!(l,f(c))
    end
    return l
end
# Out:
# biseccion2 (generic function with 2 methods)

# %%
function grafica(g::Function,a,b)
    l=biseccion2(g,a,b)
    return scatter(1:length(l),abs(l),xlabel="n",ylabel="f (c_n)",title="convergencia de f con [a,b]= [$a,$b]",yscale=:log10)
end
# Out:
# grafica (generic function with 1 method)

# %%
grafica(f,1,3)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 72.5481,369.674 596.063,369.674 596.063,23.3815 72.5481,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="72" y="23" width="524" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   240.638,364.48 240.638,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   410.942,364.48 410.942,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   581.247,364.48 581.247,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,353.611 588.21,353.611
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,193.321 588.21,193.321
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,33.0318 588.21,33.0318
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   240.638,369.674 240.638,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   410.942,369.674 410.942,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   581.247,369.674 581.247,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,369.674 72.5481,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,353.611 80.4008,353.611
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,193.321 80.4008,193.321
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,33.0318 80.4008,33.0318
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 240.638, 381.674)" x="240.638" y="381.674">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 410.942, 381.674)" x="410.942" y="381.674">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 581.247, 381.674)" x="581.247" y="381.674">30</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 41.837, 359.543)" x="41.837" y="359.543">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 55.0163, 352.69)" x="55.0163" y="352.69">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.64, 352.69)" x="60.64" y="352.69">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 47.1911, 199.253)" x="47.1911" y="199.253">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.3703, 192.401)" x="60.3703" y="192.401">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 65.994, 192.401)" x="65.994" y="192.401">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 52.8148, 38.9637)" x="52.8148" y="38.9637">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 65.994, 32.1111)" x="65.994" y="32.1111">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 334.306, 18)" x="334.306" y="18">convergencia de f con [a,b]= [1,3]</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 334.306, 397.6)" x="334.306" y="397.6">n</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:start;" transform="rotate(-90, 14.7312, 213.731)" x="14.7312" y="213.731">f (c</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:14; text-anchor:start;" transform="rotate(-90, 19.4164, 191.096)" x="19.4164" y="191.096">n)</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="87.3646" cy="23.3815" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="87.3646" cy="23.3815" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="104.395" cy="52.3326" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="104.395" cy="52.3326" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="121.425" cy="44.5413" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="121.425" cy="44.5413" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="138.456" cy="63.8421" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="138.456" cy="63.8421" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="155.486" cy="70.7893" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="155.486" cy="70.7893" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="172.517" cy="85.8816" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099f

# %%
grafica(f,-2,0)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 72.5481,369.674 596.063,369.674 596.063,23.3815 72.5481,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="72" y="23" width="524" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   240.638,364.48 240.638,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   410.942,364.48 410.942,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   581.247,364.48 581.247,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,353.15 588.21,353.15
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,287.196 588.21,287.196
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,221.243 588.21,221.243
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,155.289 588.21,155.289
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,89.3352 588.21,89.3352
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,23.3815 588.21,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   240.638,369.674 240.638,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   410.942,369.674 410.942,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   581.247,369.674 581.247,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,369.674 72.5481,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,353.15 80.4008,353.15
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,287.196 80.4008,287.196
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,221.243 80.4008,221.243
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,155.289 80.4008,155.289
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,89.3352 80.4008,89.3352
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,23.3815 80.4008,23.3815
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 240.638, 381.674)" x="240.638" y="381.674">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 410.942, 381.674)" x="410.942" y="381.674">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 581.247, 381.674)" x="581.247" y="381.674">30</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 41.837, 359.082)" x="41.837" y="359.082">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 55.0163, 352.229)" x="55.0163" y="352.229">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.64, 352.229)" x="60.64" y="352.229">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 47.1911, 293.128)" x="47.1911" y="293.128">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.3703, 286.276)" x="60.3703" y="286.276">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 65.994, 286.276)" x="65.994" y="286.276">8</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 47.1911, 227.175)" x="47.1911" y="227.175">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.3703, 220.322)" x="60.3703" y="220.322">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 65.994, 220.322)" x="65.994" y="220.322">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 47.1911, 161.221)" x="47.1911" y="161.221">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.3703, 154.368)" x="60.3703" y="154.368">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 65.994, 154.368)" x="65.994" y="154.368">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 47.1911, 95.2671)" x="47.1911" y="95.2671">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-ser

# %%
function biseccion3(f::Function,a,b,t,test=0)
    if t<=0 || t>=1
        return "$t debe de estar entre 0 y 1"
    end
    c=a+(b-a)*t
    i=1
    l=[f(c)]
    while abs(f(c))>1e-10
        if test==1    
            @show (c,f(c),f(a),f(b))
        end
        if f(c)*f(a)<0
            if test==1
                println("ac")
            end
            b=c
            c=a+(b-a)*t
            elseif f(c)*f(b)<0
            if test==1
                println("bc")
            end
            a=c
            c=a+(b-a)*t
        end
        if i==1000
            return "fail"
        end
        i=i+1
        push!(l,f(c))
    end
    return l
end
# Out:
# biseccion3 (generic function with 2 methods)

# %%
function grafica2(f,a,b,t,)
    l2=biseccion2(f,a,b)
    l3=biseccion3(f,a,b,t)
    c=scatter(1:length(l2),abs(l2),label="punto medio",xlabel="n",ylabel="f (c_n)",yscale=:log10,title="convergencia con 2 metodos",
    xlims=(-5,length(l3)+1))
    scatter!(1:length(l3),abs(l3),label="parametro $t")
    return c
end
# Out:
# grafica2 (generic function with 1 method)

# %%
grafica2(f,1,2,.1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 72.5481,369.674 596.063,369.674 596.063,23.3815 72.5481,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="72" y="23" width="524" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   116.914,364.48 116.914,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   294.376,364.48 294.376,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   471.839,364.48 471.839,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,344.823 588.21,344.823
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,279.87 588.21,279.87
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,214.917 588.21,214.917
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,149.963 588.21,149.963
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,85.01 588.21,85.01
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   116.914,369.674 116.914,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   294.376,369.674 294.376,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   471.839,369.674 471.839,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,369.674 72.5481,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,344.823 80.4008,344.823
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,279.87 80.4008,279.87
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,214.917 80.4008,214.917
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,149.963 80.4008,149.963
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,85.01 80.4008,85.01
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 116.914, 381.674)" x="116.914" y="381.674">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 294.376, 381.674)" x="294.376" y="381.674">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 471.839, 381.674)" x="471.839" y="381.674">40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 41.837, 350.755)" x="41.837" y="350.755">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 55.0163, 343.903)" x="55.0163" y="343.903">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.64, 343.903)" x="60.64" y="343.903">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 47.1911, 285.802)" x="47.1911" y="285.802">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.3703, 278.949)" x="60.3703" y="278.949">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 65.994, 278.949)" x="65.994" y="278.949">8</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 47.1911, 220.849)" x="47.1911" y="220.849">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.3703, 213.996)" x="60.3703" y="213.996">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 65.994, 213.996)" x="65.994" y="213.996">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 47.1911, 155.895)" x="47.1911" y="155.895">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.3703, 149.043)" x="60.3703" y="149.043">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 65.994, 149.043)" x="65.994" y="149.043">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 47.1911, 90.9419)" x="47.1911" y="90.9419">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.3703, 84.0893)" x="60.3703" y="84.0893">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 65.994, 84.0893)" x="65.994" y="84.0893">2</te

# %% [markdown]
# # Raíz cuadrada: El algoritmo Babilónico

# %% [markdown]
# Un ejemplo de un algoritmo sorprendente es el *algoritmo Babilónico* (o de Herón) para calcular la raiz cuadrada $\sqrt{y}$ de un número real $y$.

# %% [markdown]
# [4] ¿De cuál ecuación es raíz el número $\sqrt{y}$? ¿Cuál otra solución de esta ecuación hay?

# %% [markdown]
# Para un algoritmo, siempre necesitamos una *idea*, que toma una adivinanza $x_n$ y produce una (probablemente) mejor, $x_{n+1}$. La idea del algoritmo Babilónico es la siguiente.

# %% [markdown]
# [5] (i) Dada una adivinanza $x_n$, es posible (pero improbable) que $x_n$ ya es $\sqrt{y}$. ¿Cómo lo puedes verificar, sin utilizar (por supuesto) alguna función en Julia que calcule la raíz cuadrada? Escribe el código correspondiente.
#
# (ii) Si $x_n$ no es raíz, demuestra que $\frac{y}{x_n}$ se encuentra *del lado opuesto de $\sqrt{y}$ que $x_n$* sobre la recta real.
#
# (iii) Así, tenemos dos valores que se encuentran por dos lados diferentes de $\sqrt{y}$. ¿Cuál sería una mejor adivinanza para $x_{n+1}$? Impleméntalo.
#
# [6] (i) Utiliza esta idea para escribir una función que calcule $\sqrt{y}$ para una $y$ dada.
#
# (ii) ¿Qué tan rápido converge a la raíz cuadrada? Grafícalo.

# %% [markdown]
# ### [4]
#
# Podemos ver que $\sqrt{y}$ es una raíz de la función $f(x)= x^2 - y$. La única otra raíz de la ecuación es $-\sqrt{y}$

# %%
#[5]
function raiz(x,y)
    if x^2-y==0
        return true
    else
        return return false
    end
end
# las soluciones a la funcion son la raiz positiva y negativa de y
# Out:
# raiz (generic function with 1 method)

# %% [markdown]
# ### [5]
#
# Ya que queremos calcular $\sqrt{y}$, podemos suponer que $y\geq0$. Por simplicidad, también supondermos que la raíz buscada es la raíz cuadrada positiva de $y$. Debido a que $\mathbb{R}$ es un conjunto totalmente ordenado, tenemos que $\sqrt{y}$ y $\frac{y}{x_n}$ pueden estar relacionados de 2 maneras
#
# * $\sqrt{y} \geq \frac{y}{x_n} \implies \frac{x_n}{\sqrt{y}} \sqrt{y} \geq \frac{x_n}{\sqrt{y}}\frac{y}{x_n} \implies x_n \geq \sqrt y$
# * $\sqrt{y} \leq \frac{y}{x_n} \implies \frac{x_n}{\sqrt{y}} \sqrt{y} \leq \frac{x_n}{\sqrt{y}}\frac{y}{x_n} \implies x_n \leq \sqrt y$
#
# Cabe mencionar que, para realizar este prueba supusimos que $x_n$ es un número positivo

# %%
#[6]
function babilonico(y,x;lista=false,test=false)
    l=[float(x)]
    i=1
    while abs((l[i])^2-y) > 1e-10
        push!(l,(l[i]+(y/l[i]))/2)
        i+=1
        if test ==true
            @show (i,l[i])
        end
        if i==1000
            return "fail"
        end
    end
    if lista==true
        return l
    else
        return l[end]
    end
end
# Out:
# WARNING: Method definition babilonico(Any, Any
# babilonico (generic function with 3 methods)

# %%
babilonico(5,1,lista=true)
# Out:
# 6-element Array{Float64,1}:
#  1.0
#  3.0
#  2.33333
#  2.2381
#  2.23607
#  2.23607

# %%
A=biseccion2(x->(x^2)-5,2,3)
scatter(1:length(A),
abs(A),
label="Bisección",
yscale=:log10,
alpha=.6,title="comparacion de raices")

B=babilonico(5,1,lista=true)

scatter!(1:length(B),
abs(B-sqrt(5)),
label="Babilonico",
shape=:square,
alpha=.6)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 57.2703,384.952 596.063,384.952 596.063,23.3815 57.2703,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="57" y="23" width="539" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   220.089,379.528 220.089,28.805
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   384.055,379.528 384.055,28.805
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   548.021,379.528 548.021,28.805
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,308.105 587.981,308.105
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,167.11 587.981,167.11
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,26.1142 587.981,26.1142
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   220.089,384.952 220.089,379.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   384.055,384.952 384.055,379.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   548.021,384.952 548.021,379.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,384.952 57.2703,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,308.105 65.3522,308.105
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,167.11 65.3522,167.11
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,26.1142 65.3522,26.1142
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 220.089, 396.952)" x="220.089" y="396.952">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 384.055, 396.952)" x="384.055" y="396.952">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 548.021, 396.952)" x="548.021" y="396.952">30</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 26.5592, 314.037)" x="26.5592" y="314.037">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 39.7385, 307.184)" x="39.7385" y="307.184">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.3622, 307.184)" x="45.3622" y="307.184">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 31.9133, 173.041)" x="31.9133" y="173.041">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.0926, 166.189)" x="45.0926" y="166.189">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 50.7163, 166.189)" x="50.7163" y="166.189">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 37.537, 32.0461)" x="37.537" y="32.0461">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 50.7163, 25.1935)" x="50.7163" y="25.1935">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 326.667, 18)" x="326.667" y="18">comparacion de raices</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:0.6" cx="72.5192" cy="23.3815" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:0.6" cx="72.5192" cy="23.3815" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:0.6" cx="88.9158" cy="60.0693" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:0.6" cx="88.9158" cy="60.0693" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:0.6" cx="105.312" cy="34.9918" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:0.6" cx="105.312" cy="34.9918" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:0.6" cx="121.709" cy="44.9477" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:0.6" cx="121.709" cy="44.9477" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:0.6" cx="138.106" cy="57.4906" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:0.6" cx="138.106" cy="57.4906" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:0.6" cx="154.502" cy="85.9244" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:0.6" cx="154.502" cy="85.9244" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:0.6" cx="170.899" cy="70.1661" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:0.6" cx="170.899" cy="70.1661" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:0.6" cx="187.295" cy="82.6318" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:0.6" cx="187.295" cy="82.6318" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:0.6" cx="203.692" cy="108.857" r="3"/>
# <circle clip-path="url(#clip02)" sty

# %%
scatter(1:length(B),
abs(B-sqrt(5)),
label="Babilonico",
shape=:square,
yscale=:log10,
alpha=.6)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 57.2703,384.952 596.063,384.952 596.063,3.93701 57.2703,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="57" y="3" width="539" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   174.178,379.237 174.178,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   377.496,379.237 377.496,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   580.814,379.237 580.814,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,303.941 587.981,303.941
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,155.307 587.981,155.307
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.3522,6.67314 587.981,6.67314
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   174.178,384.952 174.178,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   377.496,384.952 377.496,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   580.814,384.952 580.814,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,384.952 57.2703,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,303.941 65.3522,303.941
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,155.307 65.3522,155.307
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   57.2703,6.67314 65.3522,6.67314
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 174.178, 396.952)" x="174.178" y="396.952">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 377.496, 396.952)" x="377.496" y="396.952">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.814, 396.952)" x="580.814" y="396.952">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 26.5592, 309.873)" x="26.5592" y="309.873">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 39.7385, 303.021)" x="39.7385" y="303.021">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.3622, 303.021)" x="45.3622" y="303.021">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 31.9133, 161.239)" x="31.9133" y="161.239">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 45.0926, 154.387)" x="45.0926" y="154.387">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 50.7163, 154.387)" x="50.7163" y="154.387">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 37.537, 12.605)" x="37.537" y="12.605">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 50.7163, 5.75244)" x="50.7163" y="5.75244">0</text>
# </g>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:0.6" points="
#   68.5192,-0.0629921 68.5192,7.93701 76.5192,7.93701 76.5192,-0.0629921 68.5192,-0.0629921
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#0099ff; fill-opacity:0.6" points="
#   69.3192,0.737008 69.3192,7.13701 75.7192,7.13701 75.7192,0.737008 69.3192,0.737008
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:0.6" points="
#   170.178,6.14955 170.178,14.1495 178.178,14.1495 178.178,6.14955 170.178,6.14955
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#0099ff; fill-opacity:0.6" points="
#   170.978,6.94955 170.978,13.3495 177.378,13.3495 177.378,6.94955 170.978,6.94955
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:0.6" points="
#   271.837,32.7579 271.837,40.7579 279.837,40.7579 279.837,32.7579 271.837,32.7579
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#0099ff; fill-opacity:0.6" points="
#   272.637,33.5579 272.637,39.9579 279.037,39.9579 279.037,33.5579 272.637,33.5579
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:0.6" points="
#   373.496,82.7302 373.496,90.7302 381.496,90.7302 381.496,82.7302 373.496,82.7302
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#0099ff; fill-opacity:0.6" points="
#   374.296,83.5302 374.296,89.9302 380.696,89.9302 380.696,83.5302 374.296,83.5302
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:0.6" points="
#   475.155,182.137 475.155,190.137 483.155,190.137 483.155,182.137 475.155,182.137
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#0099ff; fill-opacity:0.6" points="
#   475.955,182.937 475.955,189.337 482.355,189.337 482.355,182.937 475.955,182.937
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:0.6" points="
#   576.814,380.952 576.814,388.952 584.814,388.952 584.814,380.952 576.814,380.952
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#0099ff; fill-opacity:0.6" points="
#   577.614,381.752 577.614,388.152 584.014,388.152 584.014,381.752 577.614,381.752
#   "/>
# <polygon clip-path="url(#clip00)" points="
# 463.39,55.057 578.063,55.057 578.063,24.817 463.39,24.817
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none"
