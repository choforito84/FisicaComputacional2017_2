# %% [markdown]
# # Integración numérica (o "cuadratura")

# %% [markdown]
# A menudo en la física, es necesario evaluar integrales feas. [La verdad es que casi todas las integrales son feas...] Mientras que la diferenciación es un proceso que se puede llevar a cabo de manera algorítmica, siguiendo una receta, la integración no lo es. De hecho, se puede demostrar que hay integrales que no se pueden llevar a cabo de forma analítica en términos de las funciones elementales. Un ejemplo famoso es la [función error](https://es.wikipedia.org/wiki/Funci%C3%B3n_error),
#
# $$\mathrm{erf}(x) = \frac{2}{\sqrt{\pi}}\int_{0}^x e^{-t^2/2} \, dt.$$

# %% [markdown]
# Por lo tanto, necesitamos encontrar maneras de aproximar integrales definidas, de forma numérica.
#
# Recordemos que la integral
#
# $$I(f) = \int_a^b f(x) \, dx$$
#
# representa el **área debajo de la curva $y=f(x)$ entre $x=a$ y $x=b$**. Por lo tanto, la integración numérica también se llama "cuadratura numérica". [Ver, por ejemplo, https://es.wikipedia.org/wiki/Cuadratura_del_c%C3%ADrculo.]
#
# Nota que la integral $I(f)$ es una función [de hecho, un "funcional"] **lineal** de $f$. Por lo tanto, buscaremos métodos numéricos con la misma propiedad. Siguiendo la pista que vimos en el notebook sobre la interpolación, pensaremos en evaluar la función $f$ en $N+1$ **nodos** $x_j$, y buscaremos **pesos** $\alpha_i$ que den una aproximación a la integral de la forma
#
# $$Q(f) = \sum_{i=0}^N \alpha_j \, f(x_j) \qquad  (*)$$

# %% [markdown]
# **[1]** Un caso particular es una $f$ que sea **monótona**, por ejemplo el integrando $f$ que aparece en la función $\mathrm{erf}$, dado por $f(x) = e^{-x^2/2}$.
#
# (i) La idea más natural [pero ¡no necesariamente mejor!] es dividir el intervalo $[0, x]$ en $N$ intervalos iguales de longitud $h=1/N$. Dada una $x$ y una $N$, dibuja la función, así como líneas verticales punteadas (`linestyle=:dash`) en los nodos.
# Grafícalo.
#
# (ii) La idea más sencilla es aproximar la función $f$ en un intervalo dado con una recta horizontal.
# ¿Cómo podríamos calcular tanto una cota inferior como una cota superior, suponiendo que $f$ es monótona? Exprésalos en la forma de la ecuación (*). Grafícalos.
#
# Escribe una función que calcule estas áreas dadas $f$ (monótona), $a$, $b$ y $N$.
#
# (iii) ¿Cuál es la tasa de convergencia hacia el resultado exacto cuando $N \to \infty$ para $f(x) = e^{-x^2/2}$? [Pista: La función $\mathrm{erf}$ en Julia se llama... `erf`. En Julia v0.6, se encontrará en el paquete `SpecialFunctions.jl`.]
#
# **[2]** (i) Dibuja las cotas para $\mathrm{erf}(x)$.
#
# (ii) Encuentra una cota superior analítica para $\int_{t=x}^\infty e^{-t^2/t} dt$. [Pista: puedes utilizar, por ejemplo, $f(t) \le e^{-t}$ para $t$ suficientemente grande. [¿Qué tan grande?].]
#
# (iii) Así, encuentra cotas para $\lim_{x \to \infty} \mathrm{erf}(x)$. ¿Cuál valor analítica tiene?

# %%
using Plots,Interact
gr()
# Out:
# <div id="interact-js-shim">
#     <script charset="utf-8">
# (function (IPython, $, _, MathJax) {
#     $.event.special.destroyed = {
# 	remove: function(o) {
# 	    if (o.handler) {
# 		o.handler.apply(this, arguments)
# 	    }
# 	}
#     }
#
#     var OutputArea = IPython.version >= "4.0.0" ? require("notebook/js/outputarea").OutputArea : IPython.OutputArea;
#
#     var redrawValue = function (container, type, val) {
# 	var selector = $("<div/>");
# 	var oa = new OutputArea(_.extend(selector, {
# 	    selector: selector,
# 	    prompt_area: true,
# 	    events: IPython.events,
# 	    keyboard_manager: IPython.keyboard_manager
# 	})); // Hack to work with IPython 2.1.0
#
# 	switch (type) {
# 	case "image/png":
#             var _src = 'data:' + type + ';base64,' + val;
# 	    $(container).find("img").attr('src', _src);
# 	    break;
# 	case "text/latex":
# 		if (MathJax){
# 			var math = MathJax.Hub.getAllJax(container)[0];
# 			MathJax.Hub.Queue(["Text", math, val.replace(/^\${1,2}|\${1,2}$/g, '')]);
# 			break;
# 		}
# 	default:
# 	    var toinsert = OutputArea.append_map[type].apply(
# 		oa, [val, {}, selector]
# 	    );
# 	    $(container).empty().append(toinsert.contents());
# 	    selector.remove();
# 	}
#     }
#
#
#     $(document).ready(function() {
# 	function initComm(evt, data) {
# 	    var comm_manager = data.kernel.comm_manager;
#         //_.extend(comm_manager.targets, require("widgets/js/widget"))
# 	    comm_manager.register_target("Signal", function (comm) {
#             comm.on_msg(function (msg) {
#                 var val = msg.content.data.value;
#                 $(".signal-" + comm.comm_id).each(function() {
#                 var type = $(this).data("type");
#                 if (typeof(val[type]) !== "undefined" && val[type] !== null) {
#                     redrawValue(this, type, val[type], type);
#                 }
#                 });
#                 delete val;
#                 delete msg.content.data.value;
#             });
# 	    });
#
# 	    // coordingate with Comm and redraw Signals
# 	    // XXX: Test using Reactive here to improve performance
# 	    $([IPython.events]).on(
# 		'output_appended.OutputArea', function (event, type, value, md, toinsert) {
# 		    if (md && md.reactive) {
#                 // console.log(md.comm_id);
#                 toinsert.addClass("signal-" + md.comm_id);
#                 toinsert.data("type", type);
#                 // Signal back indicating the mimetype required
#                 var comm_manager = IPython.notebook.kernel.comm_manager;
#                 var comm = comm_manager.comms[md.comm_id];
#                 comm.then(function (c) {
#                     c.send({action: "subscribe_mime",
#                        mime: type});
#                     toinsert.bind("destroyed", function() {
#                         c.send({action: "unsubscribe_mime",
#                                mime: type});
#                     });
#                 })
# 		    }
# 	    });
# 	}
#
# 	try {
# 	    // try to initialize right away. otherwise, wait on the status_started event.
# 	    initComm(undefined, IPython.notebook);
# 	} catch (e) {
# 	    $([IPython.events]).on('kernel_created.Kernel kernel_created.Session', initComm);
# 	}
#     });
# })(IPython, jQuery, _, MathJax);
# </script>
#     <script>
#         window.interactLoadedFlag = true
#        $("#interact-js-shim").bind("destroyed", function () {
#            if (window.interactLoadedFlag) {
#                console.warn("JavaScript required by Interact will be removed if you remove this cell or run using Interact more than once.")
#            }
#        })
#        $([IPython.events]).on("kernel_starting.Kernel kernel_restarting.Kernel", function () { window.interactLoadedFlag = false })
#    </script>
# </div
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffa500; stroke-width:0.8; stroke-opacity:1; fill:none" stroke-dasharray="8, 5" points="
#   111.928,374.719 111.928,53.4709
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffa500; stroke-width:0.8; stroke-opacity:1; fill:none" stroke-dasharray="8, 5" points="
#   122.815,374.719 122.815,60.3536
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffa500; stroke-width:0.8; stroke-opacity:1; f
# , Number, Int64) in module Main at In[9]:3 overwritten at In[25]:3.
# WARNING: Method definition #plotear(Array{Any, 1}, Main.#plotear, Function, Number, Int64) in module Main overwritten.

# %%
function integral(f::Function,A,N::Int64;modo="sup":: String,test=false)
    B=linspace(A[1],A[2],N)
    h=((A[2]-A[1])/(N-1))
    if modo=="sup"
        total=0
        for i in 2:length(B)
            if test==true
                @show (B[i-1],B[i],f(B[i-1]),total)
            end
            total+=f(B[i-1])*h
        end
        return total
    elseif modo=="inf"
        total=0
        for i in 2:length(B)
            if test==true
                @show (B[i-1],B[i],f(B[i]),total)
            end
            total+=f(B[i])*h
        end
        return total
    end
end
# Out:
# WARNING: Method definition integral(Function
# integral (generic function with 1 method)
# , Any, Int64) in module Main at In[10]:2 overwritten at In[27]:2.
# WARNING: Method definition #integral(Array{Any, 1}, Main.#integral, Function, Any, Int64) in module Main overwritten.

# %%
B=5:60
C=[abs(erf(5)-(2/sqrt(π))*integral(x->e^(-x^2),[0,5],n,modo="inf")) for n in B]
D=[abs(erf(5)-(2/sqrt(π))*integral(x->e^(-x^2),[0,5],n,modo="sup")) for n in B]
scatter(B,C,label="superior",title="integral en comparación",alpha=1,xlabel="n",ylabel="erf(x)-integral",xscale=:log10,yscale=:log10)
scatter!(B,D,label="inferior",markershape=:square,alpha=.35)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 81.437,369.674 596.063,369.674 596.063,23.3815 81.437,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="81" y="23" width="515" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   224.988,364.48 224.988,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   463.422,364.48 463.422,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   89.1564,274.908 588.344,274.908
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   89.1564,127.048 588.344,127.048
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   81.437,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   224.988,369.674 224.988,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   463.422,369.674 463.422,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   81.437,369.674 81.437,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   81.437,274.908 89.1564,274.908
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   81.437,127.048 89.1564,127.048
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 211.706, 386.626)" x="211.706" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 224.885, 379.773)" x="224.885" y="379.773">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 450.14, 386.626)" x="450.14" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 463.319, 379.773)" x="463.319" y="379.773">1.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 48.0489, 280.84)" x="48.0489" y="280.84">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 61.2281, 273.988)" x="61.2281" y="273.988">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 66.8518, 273.988)" x="66.8518" y="273.988">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 48.0489, 132.98)" x="48.0489" y="132.98">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 61.2281, 126.127)" x="61.2281" y="126.127">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 66.8518, 126.127)" x="66.8518" y="126.127">0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 338.75, 18)" x="338.75" y="18">integral en comparación</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 338.75, 397.6)" x="338.75" y="397.6">n</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 196.528)" x="14.4" y="196.528">erf(x)-integral</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="81.437" cy="24.6971" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="81.437" cy="24.6971" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="119.196" cy="52.7195" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="119.196" cy="52.7195" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="151.121" cy="76.1119" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="151.121" cy="76.1119" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="178.775" cy="95.9091" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="178.775" cy="95.9091" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="203.168" cy="113.059" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="203.168" cy="113.059" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="224.988" cy="128.185" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="224.988" cy="128.185" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="244.727" cy="141.717" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="244.727" cy="141.717" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="262.747" cy="153.958" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="262.747" cy="153.958" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="279.324" cy="165.132" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="279.324" cy="165.132" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="294.672" cy="175.412" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="294.672" cy="175.412" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="308.96" cy="184.93" r="3"/>
# <circle clip-path="url(#clip02)" style=

# %% [markdown]
# ### [1]
#
# Podemos observar que la tasa de convergencia hacia el valor real de la integral parace ser una ley de potencias como función de n

# %%
A=linspace(0,6,100)
@manipulate for n in 40:100
    B=[(2/sqrt(π))*integral(x->e^(-x^2),[0,x],n,modo="inf") for x in A]
    C=[(2/sqrt(π))*integral(x->e^(-x^2),[0,x],n,modo="sup") for x in A]
    plot(A,B,label="inferior",title="aproximacion de la funcion error",xlabel="x",ylabel="erf(x)")
    plot!(A,C,label="superior")
    plot!(A,[erf(a) for a in A],label="original")
end
# Out:
# Interact.Options{:SelectionSlider,Int64}(Signal{Int64}(70, nactions=1),"n",70,"70",Interact.OptionDict(DataStructures.OrderedDict("40"=>40,"41"=>41,"42"=>42,"43"=>43,"44"=>44,"45"=>45,"46"=>46,"47"=>47,"48"=>48,"49"=>49…),Dict(68=>"68",89=>"89",46=>"46",85=>"85",55=>"55",42=>"42",66=>"66",58=>"58",59=>"59",74=>"74"…)),Any[],Any[],true,"horizontal")
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 45.8815,369.674 596.063,369.674 596.063,23.3815 45.8815,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="23" width="551" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   45.8815,364.48 45.8815,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   137.578,364.48 137.578,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   229.275,364.48 229.275,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   320.972,364.48 320.972,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   412.669,364.48 412.669,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   504.366,364.48 504.366,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   596.063,364.48 596.063,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,369.674 587.81,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,303.654 587.81,303.654
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,237.635 587.81,237.635
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,171.615 587.81,171.615
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,105.596 587.81,105.596
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,39.5761 587.81,39.5761
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,369.674 45.8815,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   137.578,369.674 137.578,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   229.275,369.674 229.275,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   320.972,369.674 320.972,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   412.669,369.674 412.669,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   504.366,369.674 504.366,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,369.674 596.063,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,369.674 45.8815,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,369.674 54.1342,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,303.654 54.1342,303.654
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,237.635 54.1342,237.635
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,171.615 54.1342,171.615
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,105.596 54.1342,105.596
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,39.5761 54.1342,39.5761
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 45.8815, 381.674)" x="45.8815" y="381.674">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.578, 381.674)" x="137.578" y="381.674">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 229.275, 381.674)" x="229.275" y="381.674">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 320.972, 381.674)" x="320.972" y="381.674">3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 412.669, 381.674)" x="412.669" y="381.674">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 504.366, 381.674)" x="504.366" y="381.674">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 596.063, 381.674)" x="596.063" y="381.674">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 374.174)" x="44.6815" y="374.174">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 308.154)" x="44.6815" y="308.154">0.2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 242.135)" x="44.6815" y="242.135">0.4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 176.115)" x="44.6815"

# %%
A=linspace(0,3,100)
B=[e^(-x^2) for x in A]
C=[e^(-x) for x in A]
plot(A,B,label="original")
plot!(A,C,label="cota")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.4926,384.952 596.063,384.952 596.063,3.93701 39.4926,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="3" width="557" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.4926,379.237 39.4926,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   132.254,379.237 132.254,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   225.016,379.237 225.016,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   317.778,379.237 317.778,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   410.54,379.237 410.54,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   503.301,379.237 503.301,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   596.063,379.237 596.063,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.8411,289.733 587.714,289.733
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.8411,194.468 587.714,194.468
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.8411,99.2025 587.714,99.2025
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.8411,3.93701 587.714,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,384.952 39.4926,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   132.254,384.952 132.254,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   225.016,384.952 225.016,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   317.778,384.952 317.778,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   410.54,384.952 410.54,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   503.301,384.952 503.301,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,384.952 596.063,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,384.952 39.4926,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,289.733 47.8411,289.733
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,194.468 47.8411,194.468
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,99.2025 47.8411,99.2025
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,3.93701 47.8411,3.93701
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 39.4926, 396.952)" x="39.4926" y="396.952">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 132.254, 396.952)" x="132.254" y="396.952">0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.016, 396.952)" x="225.016" y="396.952">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 317.778, 396.952)" x="317.778" y="396.952">1.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 410.54, 396.952)" x="410.54" y="396.952">2.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 503.301, 396.952)" x="503.301" y="396.952">2.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 596.063, 396.952)" x="596.063" y="396.952">3.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.2926, 294.233)" x="38.2926" y="294.233">0.25</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.2926, 198.968)" x="38.2926" y="198.968">0.50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.2926, 103.702)" x="38.2926" y="103.702">0.75</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.2926, 8.43701)" x="38.2926" y="8.43701">1.00</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,3.93701 45.1145,4.28677 50.7364,5.33412 56.3583,7.0733 61.9803,9.49479 67.6022,12.5853 73.2241,16.3282 78.846,20.703 84.468,25.6865 90.0899,31.252
#   95.7118,37.3704 101.334,44.0097 106.956,51.136 112.578,58.7131 118.199,66.7034 123.821,75.0677 129.443,83.766 135.065,92.7573 140.687,102.001 146.309,111.454
#   151.931,121.077 157.553,130.829 163.175,140.669 168.797,150.56 174.419,160.463 180.041,170.342 185.663,180.163 191.284,189.893 196.906,199.503 202.528,208.962
#   208.15,218.246

# %% [markdown]
# ### [2]
#
# Podemos encontrar que la condición para que $e^{-x^2} \leq e^{-x}$ aplicando logaritmo a ambos lados de la igualdad (la desigualdad se preserva al ser el logaritmo una función monótona). Así, encontramos que la desigualdad se cumple para $x>1$. Por otro lado, al ser la integral una funcional monónotona, podemos encontrar que
#
# $$\int_{x}^{\infty} e^{-t^} dt \leq \int_{x}^{\infty} e^{-t} dt = -e^{-t} \Big|_{x}^{\infty}=e^{-x}$$
#
# Así, podemos encontrar el límite deseado
#
# $$\lim_{x \to \infty} erf(x)=\lim_{x \to 0} =\int_{x}^{\infty} e^{-t^} dt=e^{-x} \Big|_0=1$$

# %% [markdown]
# **[3]** (i) Después de una recta horizontal, ¿cuál es la siguiente forma más natural de aproximar a la función $f$ adentro de un intervalo dado? ¿A qué aproximación de la integral lleva, expresada en la forma de la ecuación (*)? Grafícalo.
#
# (ii) Impleméntalo. Nota que este método funciona para *cualquier* función $f$, sin que tenga que ser monótona.
#
# (iii) ¿Cuál es la tasa de convergencia? ¿Cómo se compara con el método de la pregunta [1]?

# %%
#[3]
function plotear2(f::Function,x::Number,N::Int64;test=false)
    A=linspace(0,x,N)
    B=linspace(0,x,100)
    p=plot(B,[f(b) for b in B],title="partición regular",legend=false,linewidth=2)
    for i in 2:length(A)
        plot!([A[i],A[i]],[0,f(A[i])],linestyle=:dash,linecolor=:orange)
        plot!([A[i-1],A[i]],[f(A[i-1]),f(A[i])],linestyle=:dash,linecolor=:black,linewidth=4)
    end
    scatter!(A,[f(a) for a in A],markercolor=:orange)
    return p
end
plotear2(x->e^(x),2,10)
# Out:
# WARNING: Method definition plotear2(Function, Number
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 12.8259,384.952 596.063,384.952 596.063,23.3815 12.8259,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="12" y="23" width="584" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   29.3326,379.528 29.3326,28.805
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   304.444,379.528 304.444,28.805
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   579.556,379.528 579.556,28.805
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   21.5745,374.719 587.314,374.719
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   21.5745,282.392 587.314,282.392
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   21.5745,190.065 587.314,190.065
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   21.5745,97.7382 587.314,97.7382
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   29.3326,384.952 29.3326,379.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   304.444,384.952 304.444,379.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   579.556,384.952 579.556,379.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   12.8259
        end
        total=total+(abs(f(B[i])-f(B[i-1]))*h)/2+min(f(B[i-1]),f(B[i]))*h
    end
    return total
end
# Out:
# WARNING: Method definition integral2(Function
# integral2 (generic function with 1 method)
# , Any, Int64) in module Main at In[53]:2 overwritten at In[55]:2.
# WARNING: Method definition #integral2(Array{Any, 1}, Main.#integral2, Function, Any, Int64) in module Main overwritten.

# %%
B=5:60
C=[abs(erf(5)-(2/sqrt(π))*integral2(x->e^(-x^2),[0,5],n)) for n in B]
scatter(B,C,label="superior",title="integral2 en comparación",alpha=1,xlabel="n",ylabel="erf(x)-integral2",xscale=:log10,yscale=:log10)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 72.5481,369.674 596.063,369.674 596.063,23.3815 72.5481,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="72" y="23" width="524" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   218.579,364.48 218.579,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   461.131,364.48 461.131,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,270.541 588.21,270.541
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   80.4008,107.028 588.21,107.028
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   218.579,369.674 218.579,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   461.131,369.674 461.131,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,369.674 72.5481,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,270.541 80.4008,270.541
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.5481,107.028 80.4008,107.028
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 205.297, 386.626)" x="205.297" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 218.476, 379.773)" x="218.476" y="379.773">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 447.849, 386.626)" x="447.849" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 461.028, 379.773)" x="461.028" y="379.773">1.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 41.837, 276.473)" x="41.837" y="276.473">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 55.0163, 269.62)" x="55.0163" y="269.62">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.64, 269.62)" x="60.64" y="269.62">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 47.1911, 112.96)" x="47.1911" y="112.96">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 60.3703, 106.107)" x="60.3703" y="106.107">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 65.994, 106.107)" x="65.994" y="106.107">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 334.306, 18)" x="334.306" y="18">integral2 en comparación</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 334.306, 397.6)" x="334.306" y="397.6">n</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 196.528)" x="14.4" y="196.528">erf(x)-integral2</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="72.5481" cy="23.3815" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="72.5481" cy="23.3815" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="110.959" cy="73.844" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="110.959" cy="73.844" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="143.435" cy="135.521" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="143.435" cy="135.521" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="171.567" cy="208.418" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="171.567" cy="208.418" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="196.382" cy="294.965" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="196.382" cy="294.965" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="218.579" cy="321.251" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="218.579" cy="321.251" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="238.659" cy="323.385" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="238.659" cy="323.385" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="256.99" cy="325.505" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="256.99" cy="325.505" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="273.853" cy="327.494" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="273.853" cy="327.494" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="289.466" cy="329.372" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="289.466" cy="329.372" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="304.001" cy="331.146" r="3"/>
# <circle clip-path="url(#clip02)" style=

# %%
B=5:60
C=[abs(log(2)-integral2(x->(1/x),[1,2],n)) for n in B]
scatter(B,C,label="superior",title="integral2 en comparación",alpha=1,xlabel="n",ylabel="erf(x)-integral2",xscale=:log10,yscale=:log10)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 63.6592,369.674 596.063,369.674 596.063,23.3815 63.6592,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="63" y="23" width="533" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   212.17,364.48 212.17,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   458.84,364.48 458.84,28.5758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   71.6453,259.029 588.077,259.029
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   71.6453,110.679 588.077,110.679
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   63.6592,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   212.17,369.674 212.17,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   458.84,369.674 458.84,364.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   63.6592,369.674 63.6592,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   63.6592,259.029 71.6453,259.029
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   63.6592,110.679 71.6453,110.679
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 198.887, 386.626)" x="198.887" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 212.067, 379.773)" x="212.067" y="379.773">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 445.558, 386.626)" x="445.558" y="386.626">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 458.737, 379.773)" x="458.737" y="379.773">1.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 38.3022, 264.961)" x="38.3022" y="264.961">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 51.4815, 258.108)" x="51.4815" y="258.108">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 57.1052, 258.108)" x="57.1052" y="258.108">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 38.3022, 116.611)" x="38.3022" y="116.611">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 51.4815, 109.758)" x="51.4815" y="109.758">-</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 57.1052, 109.758)" x="57.1052" y="109.758">3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 329.861, 18)" x="329.861" y="18">integral2 en comparación</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 329.861, 397.6)" x="329.861" y="397.6">n</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 196.528)" x="14.4" y="196.528">erf(x)-integral2</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="63.6592" cy="23.3815" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="63.6592" cy="23.3815" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="102.723" cy="51.961" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="102.723" cy="51.961" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="135.75" cy="75.3584" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="135.75" cy="75.3584" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="164.36" cy="95.1634" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="164.36" cy="95.1634" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="189.595" cy="112.332" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="189.595" cy="112.332" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="212.17" cy="127.483" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="212.17" cy="127.483" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="232.59" cy="141.04" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="232.59" cy="141.04" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="251.233" cy="153.307" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="251.233" cy="153.307" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="268.382" cy="164.509" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="268.382" cy="164.509" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="284.26" cy="174.814" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="284.26" cy="174.814" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="299.042" cy="184.357" r="3"/>
# <circle clip-path="url(#clip02)" style="fi

# %% [markdown]
# **[4]** Lo que estamos haciendo es aproximar la función $f$ en cada sub-intervalo. La siguiente aproximación es una cuadrática, que da una regla llamada el **método de Simpson**.
#
# (i) Utiliza el método de interpolación de Lagrange para encontrar una expresión analítica para un polinomio que interpola la función $f$ en tres puntos: $x_i$, $x_{i+1}$, y el punto medio $m$ entre $x_i$ y $x_{i+1}$.
#
# (ii) Integra este polinomio para encontrar $\int_{x_i}^{x_{i+1}} f(t) \, dt$.
#
# (iii) Así, encuentra una aproximación para $\int_{a}^{b} f(t) \, dt$.
#
# (iv) Encuentra numéricamente la tasa de convergencia del método.

# %%
#[4]
function L(t,j,X;test=false)
    total=1
    for i in 1:length(X)
        if test==true
            @show (X[i],total)
        end
        if i==j
            continue
        end
        total=total*((t-X[i])/(X[j]-X[i]))
    end
    return total
end
function integral3(f::Function,A,n::Int64;test=false)
    B=linspace(A[1],A[2],n)
    total2=0
    for i in 2:length(B)
        #definicion de una martrix con los puntos a interpolar de cada intervalo
        M=[B[i-1] f(B[i-1]);(B[i-1]+B[i])/2 f((B[i-1]+B[i])/2);B[i] f(B[i])]
        #definicion del polinomio de lagrange para esos puntos
        function interpoly(t)
            total=0
            for i in 1:size(M)[1]
                total=total+M[i,2]*L(t,i,M[:,1])
            end
        return total
        end
        total2=total2+integral2(interpoly,[B[i-1],B[i]],100)
    end
    return total2
end
# Out:
# WARNING: Method definition L(Any
# syntax: incomplete: premature end of input
# , Any, Any) in module Main at In[87]:3 overwritten at In[94]:3.
# WARNING: Method definition #L(Array{Any, 1}, Main.#L, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition integral3(Function, Any, Int64) in module Main at In[87]:23 overwritten at In[94]:16.
# WARNING: Method definition #integral3(Array{Any, 1}, Main.#integral3, Function, Any, Int64) in module Main overwritten.

# %%
println(integral3(x->e^(-x/9),[0,9],60))
println(9*(1-(1/e)))
# Out:
# 5.689085043515857
# 5.6890850294570185

# %% [markdown]
# Cabe mencionar que hay métodos muy precisos, por ejemplo la llamada **cuadratura de Gauss**, que funcionan si la función es suave, en los cuales se utiliza la interpolación de Lagrange para aproximar una función con un polinomio **globalmente en todo el rango $[a,b]$, y luego ¡se integra el polinomio!
#
# Estos métodos se pueden extender a integrales en más dimensiones.
